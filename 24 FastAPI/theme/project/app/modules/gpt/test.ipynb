# %%
# app/modules/gpt/test.ipynb

# Инициализация и общие настройки
import requests
import json

BASE_URL = "http://127.0.0.1:8000"
AUTH_URL = f"{BASE_URL}/auth"
GPT_URL = f"{BASE_URL}/gpt"

HEADERS_JSON = {
    "Content-Type": "application/json"
}

def print_response(resp):
    print("Status:", resp.status_code)
    try:
        data = resp.json()
        print("Response:", data)
        if isinstance(data, dict) and "detail" in data:
            print("Detail:", data["detail"])
    except Exception:
        print("Response text:", resp.text)

# %%
# POST /auth/register — регистрация нового пользователя

payload_register = {
    "name": "Тестовый пользователь GPT",
    "login": "user1",
    "password": "12345"
}

resp = requests.post(
    f"{AUTH_URL}/register",
    headers=HEADERS_JSON,
    data=json.dumps(payload_register)
)
print("Register user")
print_response(resp)
# Out:
# Register user
# Status: 201
# Response: {'name': 'Тестовый пользователь GPT', 'login': 'user_gpt', 'id': 3, 'is_admin': False, 'created_at': '2026-01-20T09:56:35'}

# %%
# Авторизация пользователя и подготовка headers

# POST /auth/token — логин
payload_login = {
    "username": "user1",
    "password": "12345"
}

resp = requests.post(f"{AUTH_URL}/token", data=payload_login)
print("Login")
print_response(resp)

token = resp.json().get("access_token")

HEADERS_AUTH = {
    "Authorization": f"Bearer {token}",
    "Content-Type": "application/json"
}
# Out:
# Login
# Status: 200
# Response: {'access_token': 'eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJzdWIiOiJ1c2VyX2dwdCIsImV4cCI6MTgwMDQzOTAzNX0.YK5i3mnZJHXlzh3V8_iZDRJ7xSUXZ3miemt25J8VWyA', 'token_type': 'bearer', 'user': {'name': 'Тестовый пользователь GPT', 'password': '$5$rounds=535000$viI/zUKyHqwcto/Z$TlJZ5dhQiUR/p/wv2VmNt/t933W47uIS1X9wHTztPw4', 'id': 3, 'created_at': '2026-01-20T09:56:35', 'login': 'user_gpt', 'is_admin': False}}

# %%
# POST /gpt — тест GPT

prompt_payload = {
    "prompt": "Привет, расскажи короткий стих о котиках",
    "temperature": 0.7,
    "max_tokens": 100
}

resp = requests.post(
    GPT_URL,
    headers=HEADERS_AUTH,
    data=json.dumps(prompt_payload)
)
print("Call GPT")
print_response(resp)
# Out:
# Call GPT
# Status: 200
# Response: {'answer': 'Котик серый на окне,  \nСолнечный свет в его игре.  \nЛасково мявкает он,  \nСловно сказки шепчет в сон.  \n\nГладит лапкой мягкий плед,  \nСпит, как будто в сказочном след.  \nСветит звезда в вышине,  \nКотик — радость в каждом дне.'}
