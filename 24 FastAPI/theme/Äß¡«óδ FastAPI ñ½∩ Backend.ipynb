# %% [markdown]
# # Создание первого приложения
#
# ## Подготовка среды на ПК Windows (версия 10 и выше)
#
# ### Шаг 1. Установка редактора VS Code
#
# 1. Перейдите на официальный сайт: **https://code.visualstudio.com**.
# 2. Скачайте установщик для **Windows**.
# 3. Запустите скачанный файл (`VSCodeSetup-x64.exe`).
# 4. В мастере установки:
#    - примите лицензионное соглашение;
#    - выберите папку установки (по умолчанию — `C:\Users\<ваш_пользователь>\AppData\Local\Programs\Microsoft VS Code`);
#    - отметьте галочки:
#      - **«Add to PATH»** (чтобы запускать VS Code из командной строки);
#      - **«Register Code as an editor for supported file types»** (ассоциировать файлы с VS Code);
#    - нажмите **Install**.
# 5. После завершения нажмите **Finish**.

# %% [markdown]
# ### Шаг 2. Установка Python
#
# 1. Перейдите на **python.org**.
# 2. В разделе **Downloads** скачайте **Python 3.x** для Windows.
# 3. Запустите установщик.
# 4. В первом окне **отметьте галочку «Add Python to PATH»**.
# 5. Нажмите **Install Now**.
# 6. Проверьте версию в командной строке (`Win` + `R` → `cmd` → `Enter`):
#    ```cmd
#    python --version
#    ```
# Должна отобразиться версия (например, Python 3.11.5).

# %% [markdown]
# ### Шаг 3. Установка расширений в VS Code
#
# 1. Откройте VS Code.
# 2. Нажмите Ctrl + Shift + X (вкладка Extensions).
# 3. В строке поиска введите и установите:
# - Python (от Microsoft);
# - Jupyter (от Microsoft).

# %% [markdown]
# ### Шаг 4. Создание папки проекта
#
# 1. Откройте Проводник (Win + E).
#
# 2. В адресной строке Проводника введите:
# ```explorer
# %USERPROFILE%\projects
# ```
# и нажмите Enter.
#
# 3. Если папка projects не существует, создайте её: правой кнопкой мыши → Создать → Папку, назовите projects.
#
# 4. Внутри папки projects создайте папку проекта, например с именем fastapi.
#
# Полный путь через переменную:
# ```explorer
# %USERPROFILE%\projects\fastapi
# ```
# В проводнике он развернётся в физический путь, например: C:\Users\Ivanov\projects\fastapi.

# %% [markdown]
# ### Шаг 5. Открытие папки в VS Code
#
# 1. В VS Code нажмите Ctrl + KCtrl + O или выберите File → Open Folder.
# 2. Укажите путь: C:\Users\<ваш_пользователь>\projects\fastapi.
# 3. Нажмите Select Folder.

# %% [markdown]
# ### Шаг 6. Открытие терминала
#
# В VS Code откройте терминал (Ctrl + ` или Terminal → New Terminal).

# %% [markdown]
# ### Шаг 7. Создание виртуального окружения
#
# 1. В терминале выполните:
# ```cmd
# python -m venv .venv
# ```
#
# 2. Слева в проводнике VSCode создайте в корне проекта папку .vscode, внутри нее файл settings.json с содержимым:
# ```json
# {
#   "terminal.integrated.profiles.windows": {
#     "PowerShell": {
#       "path": "C:\\Windows\\System32\\WindowsPowerShell\\v1.0\\powershell.exe",
#       "args": [
#         "-NoExit",
#         "-Command",
#         ".\\.venv\\Scripts\\Activate.ps1"
#       ]
#     }
#   },
#   "terminal.integrated.defaultProfile.windows": "PowerShell"
# }
# ```
#
# 3. Закройте терминал и откройте терминал заново
#
# После повторного открытия терминала автоматически активируется виртуальное окружение.
# Убедитесь в этом - приглашение в командной строке будет начинаться с (.venv), например:
# ```cmd
# (.venv) PS C:\Users\user\projects\fastapi>
# ```

# %% [markdown]
# ## Первое приложение на FastAPI
#
# Давайте создадим простое приложение на FastAPI с маршрутом, который выводит "Hello, World!".
#
# ### Шаг 1. **Установка FastAPI и Uvicorn**:
#
# Для начала нужно установить **FastAPI** и сервер **Uvicorn**. Для этого в файле requirements.txt пропишите зависимости:
#
# ```requirements.txt
# fastapi
# uvicorn
# ```
#
# Обновляем pip:
# ```cmd
# python -m pip install --upgrade pip
# ```
#
# Установите зависимости:
# ```cmd
# pip install -r requirements.txt
# ```

# %% [markdown]
# ### Шаг 2. **Создание приложения**:
#
# Теперь создадим каталог `app`, в нем файл `main.py`:
#
# ```python
# # app/main.py
#
# from fastapi import FastAPI # Импортируем класс FastAPI из библиотеки FastAPI — он нужен для создания веб‑приложения
# import uvicorn              # Импортируем библиотеку uvicorn — это ASGI‑сервер, который будет запускать наше приложение
#
# # Создаём FastAPI приложение
# app = FastAPI()             # Создаём экземпляр приложения FastAPI и присваиваем его переменной `app`;
#                             # теперь `app` — основной объект, через который настраиваем маршруты
#
# @app.get("/")               # Декоратор, который регистрирует функцию как обработчик GET‑запросов к корневому пути `/`;
# def root():                 # Определяем функцию‑обработчик для маршрута `/`;
#                             # имя функции может быть любым, но должно быть уникальным в рамках модуля
#     return {"message": "Hello, World!"}  # Возвращаем словарь в формате JSON — FastAPI автоматически преобразует его в HTTP‑ответ;
#                                          # клиент получит JSON с полем `"message": "Hello, World!"`
#
# # Запуск
# if __name__ == "__main__":  # Проверяем, запускается ли скрипт напрямую (а не импортируется как модуль)
#     uvicorn.run(            # Вызываем функцию `run` из библиотеки Uvicorn — она запускает ASGI‑сервер
#         "app.main:app",     # Строка формата 'модуль:объект':
#                             # - 'app' — имя пакета/папки, где лежит код;
#                             # - 'main' — имя Python‑файла (без расширения .py), где определён объект приложения;
#                             # - второй 'app' — имя объекта FastAPI (экземпляра класса `FastAPI`), объявленного в файле `main.py`
#         host="127.0.0.1",   # Указываем IP‑адрес, на котором будет слушать сервер;
#                             # '127.0.0.1' — локальный хост (только для текущего компьютера)
#         port=8000,          # Задаём порт, на котором будет работать сервер; 8000 — распространённый выбор для разработки
#         log_level="info",   # Устанавливаем уровень логирования: 'info' — будут выводиться информационные сообщения
#                             # (например, о принятых запросах, ошибках и т. д.)
#         reload=True         # Включаем режим автоперезагрузки: при изменении кода сервер автоматически перезапустится;
#                             # удобно при разработке, но не рекомендуется для продакшена
#     )
# ```

# %% [markdown]
# ### Шаг 3. **Запуск приложения**
# ```cmd
# python -m app.main
# ```

# %% [markdown]
# ### Шаг 4. **Проверка работы**
#
# 1. Откройте браузер и перейдите по адресу:
# ```explorer
# http://127.0.0.1:8000/
# ```
#
# Вы увидите следующий JSON-ответ:
# ```json
# {"message": "Hello, World!"}
# ```
#
# 2. В терминале вы увидите примерно такие строки:
#
# ```cmd
# INFO:     127.0.0.1:50532 - "GET / HTTP/1.1" 200 OK
# INFO:     127.0.0.1:50532 - "GET /favicon.ico HTTP/1.1" 404 Not Found
# ```
#
# 3. Для того, чтобы не отображался статус 404 об отстутствии favicon.ico поместите файл favicon.ico в каталог app, обновите страницу в бразере.
#
# В этом случае ошибка 404 больше не будет появляться после обновления:
# ```cmd
# INFO:     127.0.0.1:50532 - "GET / HTTP/1.1" 200 OK
# ```

# %% [markdown]
# ### 5. **Документация API**:
#
# После того как приложение запущено, FastAPI автоматически генерирует документацию для вашего API. Вы можете найти её по адресу:
#
# - http://127.0.0.1:8000/docs          - для интерактивной документации
# - http://127.0.0.1:8000/redoc         - для более статичной, но красивой документации
# - http://127.0.0.1:8000/openapi.json  - документация в формате JSON

# %% [markdown]
# # Маршрутизация
#
# FastAPI использует декораторы для привязки функций‑обработчиков к HTTP‑маршрутам.
#
# Роутер (APIRouter)
# - служит контейнером для группы связанных маршрутов;
# - позволяет модульно организовывать код (например, отдельные роутеры для пользователей, товаров и т. п.);
# - поддерживает префиксы и теги для группировки в документации.
# - HTTP‑методы как декораторы
#
# Примеры декораторов:
# ```python
# @router.get() — для GET‑запросов;
# @router.post() — для POST;
# @router.put(), @router.delete() и др. — для остальных методов.
# ```
#
# ## Примеры маршрутизации
#
# ### Шаг 1. Создание файла маршрутов
#
# Создайте файл app/modules/examples/routes/route.py (скачайте из каталога материалов).
#
# ### Шаг 2. Подключение файла маршрутов в main.py
#
# В файле app/main.py в блоке импортов добавьте:
# ```python
# from .modules.examples.routes.route import router as examples_routes
# ```
#
# В файле app/main.py перед в блоке подключения маршрутов добавьте:
# ```python
# # Подключение маршрутов
# ...
# app.include_router(examples_routes)
# ```
#
# ### Шаг 3. Тестирование маршрутов
#
# В файл requirements.txt добавьте библиотеку requests:
# ```ini
# ...
# requests
# ```
#
# Выполните установку зависимостей:
# ```cmd
# pip install -r requirements.txt
# ```
#
# Создайте файл app/modules/examples/routes/test.ipynb

# %% [markdown]
# # Логирование
#
# В проект добавляем единый модуль логирования:
# - логи позволяют отслеживать обращения к API, ошибки, предупреждения и служебные сообщения в едином формате
# - наличие истории логов, разложенной по датам, упрощает отладку и поиск причин сбоев как на этапе разработки, так и в продакшене
# - выделение логирования в отдельный модуль отделяет техническую инфраструктуру от бизнес-логики и делает код чище и поддерживаемее
# - реализация поддерживает как асинхронное, так и синхронное логирование, что важно для разных частей приложения
# - дополнительно предусмотрена гибкая настройка вывода логов в консоль и безопасная сериализация данных для записи в файлы
#
# ## Добавляем файл log.py
#
# 1. Создаем каталог utils.
#
# 2. В каталог помещаем файл log.py
#
# ## Устанавливаем библиотеки для асинхронного логирования
#
# В файл requirements.txt добавьте библиотеки requests:
# ```ini
# ...
# aiologger
# aiofiles
# ```
#
# Выполните установку зависимостей:
# ```cmd
# pip install -r requirements.txt
# ```
#
# ## В файле main.py добавляем:
#
# - импортируем файл логгера:
# ```python
# from .utils.log import Log  # Импорт логгера
# ```
#
# ## Добавляем асинхронный контект для управления жизненным циклом приложения
#
# В файле main.py добавляем блок lifespan:
# ```python
# # Контекст управления жизненным циклом приложения
# from contextlib import asynccontextmanager
# @asynccontextmanager
# async def lifespan(app: FastAPI):
#
#     # Создание объекта логгера
#     app.state.log = Log()
#
#     # Лог запуска приложения
#     app.state.log.log_info_sync(target="startup", message="Запуск приложения")
#
#     # Контекст приложения
#     yield
#
#     # Лог остановки приложения
#     app.state.log.log_info_sync(target="startup", message="Остановка приложения")
#
#     # Shutdown для корректного завершения работы асинхронных логгеров
#     await app.state.log.shutdown()
# ```
#
# Указываем функцию контекста при создании приложения:
# ```python
# app = FastAPI(lifespan=lifespan)
# ```
#
# ## Проверка
#
# После запуска (или перезапуска) приложения рядом с каталогом app должен автоматически появиться каталог log

# %% [markdown]
# # Валидация
#
# Pydantic — библиотека Python для валидации и трансформации данных: она автоматически проверяет, соответствуют ли входящие данные заданным типам и правилам, и при необходимости преобразует их в нужный формат.
#
# Её ключевые задачи:
# - гарантировать корректность данных (например, что цена — положительное число, а email — валидный);
# - упростить работу с API (автоматически разбирать JSON‑запросы и формировать ответы);
# - снизить количество ошибок за счёт строгой типизации и понятных сообщений об ошибках.
#
# Чаще всего Pydantic используют в веб‑фреймворках вроде FastAPI для обработки входных данных и генерации документации.
#
# ## Примеры
#
# ### Шаг 1. Создание файла маршрутов
#
# Создайте файл app/modules/examples/notes/route.py (скопируйте из каталога материалов).
#
# #### Что передается в параметре request
#
# `request: Request` — это контекст текущего HTTP-запроса, созданный FastAPI, содержащий все данные запроса и доступ к состоянию приложения.
# Он не приходит от клиента как параметр и не создаётся вручную, параметр request генерируется FastAPI автоматически.
#
# Что содержит:
#
# ##### Основные данные
# ```code
# - `request.method` — HTTP-метод
# - `request.url` — полный URL
# - `request.headers` — заголовки
# - `request.cookies`
# - `request.query_params`
# - `request.path_params`
# ```
#
# ##### Клиент
# ```code
# - `request.client.host`
# - `request.client.port`
# ```
#
# ##### Тело запроса
# ```code
# - `await request.json()`
# - `await request.body()`
# - `await request.form()`
# ```
# ! Тело можно прочитать **один раз**
#
# ### Шаг 2. Подключение файла маршрутов в main.py
#
# В файле app/main.py в блоке импортов добавьте:
# ```python
# from .modules.examples.notes.route import router as examples_notes
# ```
#
# В файле app/main.py перед блоком "Запуск" добавьте блок подключения маршрутов:
# ```python
# # Подключение маршрутов
# app.include_router(examples_notes)
# ```
#
# ### Шаг 3. Тестирование маршрутов
#
# Создайте файл app/modules/examples/notes/test.ipynb,
# выполните тестирование каждого блока.

# %% [markdown]
# # Настройки
#
# Файлы .env и .env_example используются для хранения конфигурации приложения отдельно от кода.
#
# мы храним их в корне проекта, чтобы удобно управлять настройками (порты, режимы, флаги логирования, ключи и т.п.)
# без изменения исходников. Переменные из .env загружаются приложением при старте и действуют
# в контексте процесса приложения; они не видны всем пользователям операционной системы,
# а доступны только тому процессу (и его дочерним процессам), который их загрузил,
# и существуют до тех пор, пока приложение запущено.
#
# ## Чем отличается .env и .env_example
#
# ### .env
#
# Файл конфигурации с конкретными значениями переменных окружения (в том числе чувствительными),
# который используется при запуске приложения и обычно не коммитится в репозиторий
#
# ### .env_example
#
# Пример (шаблон) с перечнем всех необходимых переменных и безопасными или пустыми значениями,
# который хранится в репозитории и показывает, как должен выглядеть .env
#
# ## Создадим файлы .env и .env_example
#
# Создаем файл .env:
# ```ini
# # .env
#
# # Отображать лог в терминале
# LOG_PRINT = 1
# ```
#
# Копируем файл .env в файл .env_example
#
# Создаем каталог base
#
# ## Создание файла config.py
#
# Создаем файл config.py:
# ```python
# # config.py
#
# from pydantic_settings import BaseSettings, SettingsConfigDict
#
# class Settings(BaseSettings):
#
#     LOG_PRINT: str = "1"
#
#     model_config = SettingsConfigDict(
#         env_file=".env",
#         extra="ignore"
#     )
#
# settings = Settings()
# ```
#
# ## Установка библиотек
#
# python-dotenv - для чтение переменных окружения
# pydantic-settings - для чтения настроек
#
# Добавьте в файл requirements.txt:
# ```ini
# ...
# python-dotenv
# pydantic-settings
# ```
#
# Выполните установку зависимостей:
# ```cmd
# pip install -r requirements.txt
# ```
#
# ## Чтение переменных окружения
#
# В файле main.py после импортов добавьте:
# ```python
# # Загрузка переменных окружения
# from dotenv import load_dotenv
# load_dotenv()
# ```
#
# ## Добавляем middleware для обработки CORS-запросов
#
# Этот код добавляет в FastAPI middleware CORS (Cross-Origin Resource Sharing),
# которое разрешает браузерам выполнять запросы к API с других доменов:
# в данном случае разрешены запросы с любых источников, с любыми HTTP-методами и заголовками,
# а также с передачей credentials (cookies, заголовки авторизации),
# что обычно используется для упрощения разработки и интеграции фронтенда с бэкендом.
#
# В файле main.py после создания объект приложения app добавьте:
# ```python
# # Обработка COSR-запросов
# from fastapi.middleware.cors import CORSMiddleware
# app.add_middleware(
#     CORSMiddleware,
#     allow_origins=["*"],
#     allow_credentials=True,
#     allow_methods=["*"],
#     allow_headers=["*"],
# )
# ```
#
# ## Тестирование
#
# Попробуйте закрыть, открыть приложение. Логи должны отображаться как в файлах, так и в терминале,
# т.к. настройка LOG_PRINT = '1'.
#
# Если LOG_PRINT = '0', то логирование будет только в файлах каталога log.

# %% [markdown]
# # База данных
#
# ## Создание каталога base
#
# Рядом с каталогом app создайте каталог base для хранения базы данных
#
# ## Добавим настройку подключения к базе данных
#
# В файлах .env и .env_example добавьте настройку:
# ```ini
# ...
# # База данных
# DATABASE_URL = sqlite+aiosqlite:///./base/db.sqlite
# ```
#
# В файле app/config.py добавьте аттрибут DATABASE_URL:
# ```
# ...python
# class Settings(BaseSettings):
#
#     LOG_PRINT: str = "1"
#     DATABASE_URL: str
# ```
#
# ## Установим зависимости для работы с базой данных
#
# В файл requirements.txt добавьте библиотеки:
# ```ini
# ...
# sqlalchemy
# aiosqlite
# ```
#
# Установите зависимостей:
# ```cmd
# pip install -r requirements.txt
# ```
#
# ## Создадим модель для заметок
#
# Создайте каталог app/modules/notes
# Создайте файл с описанием модели app/models/notes/model.py:
# ```python
# # app/modules/notes/model.py
#
# from sqlalchemy import Column, Integer, String, Text  # типы колонок SQLAlchemy
# from app.utils.database import Base                  # базовый класс Declarative Base
#
#
# class Note(Base):
#     """
#     ORM-модель заметки.
#
#     Отражает таблицу notes в базе данных.
#     Используется для:
#     - создания заметок
#     - чтения данных
#     - обновления и удаления записей
#     """
#
#     __tablename__ = "note"   # имя таблицы в базе данных
#
#     id = Column(
#         Integer,
#         primary_key=True,    # первичный ключ
#         index=True           # индекс для быстрого поиска по id
#     )
#
#     title = Column(
#         String(100),         # заголовок заметки (до 100 символов)
#         nullable=False       # обязательное поле
#     )
#
#     content = Column(
#         Text,                # текст заметки
#         nullable=False       # обязательное поле
#     )
# ```
#
# ## Добавим утилиту для работы с базой данных
#
# В каталог app/utils добавьте файл database.py:
# ```python
# # database.py
#
# from sqlalchemy.ext.asyncio import create_async_engine, AsyncSession
# from sqlalchemy.orm import sessionmaker
# from app.config import settings
# from sqlalchemy.orm import declarative_base
#
# # Создаём Base
# Base = declarative_base()
#
# # Берём URL из настроек
# SQLALCHEMY_DATABASE_URL = settings.DATABASE_URL
#
# # Асинхронный движок
# engine = create_async_engine(
#     SQLALCHEMY_DATABASE_URL,
#     echo=True
# )
#
# # Асинхронная сессия
# AsyncSessionLocal = sessionmaker(
#     bind=engine,
#     class_=AsyncSession,
#     expire_on_commit=False
# )
#
# # Dependency для FastAPI
# async def get_db():
#     async with AsyncSessionLocal() as session:
#         yield session
#
# # Инициализация базы данных
# async def init_db():
#     async with engine.begin() as conn:
#         await conn.run_sync(Base.metadata.create_all)
#
# # Закрытие базы данных
# async def close_db():
#     await engine.dispose()
# ```
#
# ## Добавим инициализацию и закрытие базы данных в main.py
#
# В блоке импортов добавьте:
# ```python
# from app.utils.database import init_db  # Инициализация базы данных
# from app.utils.database import close_db # Закрытие базы данных
# ```
#
# В функции управдения жизненным циклом добавьте инициализацию и закрытие базы данных
# ```python
# async def lifespan(app: FastAPI):
#
#     # Создание объекта логгера
#     app.state.log = Log()
#
#     # Лог запуска приложения
#     await app.state.log.log_info(target="startup", message="Запуск приложения")
#
#     # Инициализация базы данных
#     await init_db(app.state.log)
#
#     ...
#
#     yield
#
#     ...
#
#     # Закрытие базы данных
#     await close_db()
# ```
#
# ## Создание базы данных
#
# Выполнение запуск приложения, если оно было остановлено:
# ```cmd
# python -m app.main
# ```
#
# В результате запуска в каталоге base появится файл базы данных db.sqlite.
#
# Структуру базы данных можно просмотреть, установив в редакторе VS Code расширение "SQLite Viewer".
# В базе данных появится таблица 'note'.
#
# ## Создание маршрутов
#
# Скопируем схему данных из модуля app/modules/examples/notes/schema.py
# в файл app/modules/notes/schema.py
#
# Создадим файл app/modules/notes/route.py (код здесь не приводится, возьмите из материалов).
#
# ### Пояснение про Depends(get_db)
#
# Схема выполнения:
#
# ```text
# HTTP REQUEST
#     |
#     v
# FastAPI получает запрос
#     |
#     v
# Разбор сигнатуры эндпоинта
#     |
#     |--> db: AsyncSession = Depends(get_db)
#     |        |
#     |        v
#     |   Вызов get_db()
#     |        |
#     |        v
#     |   async with async_session_maker() as session:
#     |        |
#     |        v
#     |   yield session   <───────────────┐
#     |        |                           │
#     |        v                           │
#     |   session передаётся в эндпоинт    │
#     |                                    │
#     v                                    │
# Выполняется get_notes(...)               │
#     |                                    │
#     |--> await db.execute(...)           │
#     |--> return notes                    │
#     |                                    │
#     v                                    │
# FastAPI ловит return                     │
#     |                                    │
#     v                                    │
# Возврат управления в get_db() ──────────┘
#     |
#     v
# Выход из async with
#     |
#     |--> session.close()
#     |--> connection возвращается в pool
#     |
#     v
# RESPONSE → клиенту
# ```
#
# ## Подключение маршрутов в файле main.py
#
# Подключите файл app/modules/notes/route.py в файле main.py:
# ```python
# from .modules.notes.route import router as routes_notes
# ...
# app.include_router(routes_notes)
# ```
#
# ## Тестирование
#
# Протестируем маргруты, для этого скопируем файл app/modules/examples/notes/test.ipynb
# в файл app/modules/notes/test.ipynb, в нем нужно будет поменять base_url:
# ```python
# # Базовая конфигурация
# base_url = "http://127.0.0.1:8000/notes"
# ```
#
# Запустите приложение и протестируйте маршруты. Теперь данные должны редактироваться в базе данных в таблице 'note'.

# %% [markdown]
# # Миграции
#
# **Миграции** — это управляемые изменения структуры базы данных (таблиц, колонок, индексов и т.д.), которые применяются по мере развития приложения.
#
# ## Например:
# - Добавили новую таблицу `users` → создаём миграцию, которая создаст таблицу в базе
# - Добавили колонку `email` в `notes` → миграция добавит колонку, не затронув старые данные
# - Поменяли тип колонки → миграция аккуратно изменит схему без потери данных (если возможно)
#
# ## Зачем нужны миграции
#
# 1. **История изменений** – понятно, как база менялась с версии к версии
# 2. **Безопасность данных** – структура изменяется без ручного вмешательства, данные не теряются
# 3. **Команда/DevOps** – все разработчики и серверы используют одинаковую схему, просто выполняя миграции
# 4. **Автоматизация** – можно откатывать изменения (`rollback`) или применять их на новом сервере без ошибок
#
# ## Подключение Alembic
#
# ### Установка зависимостей
#
# Добавьте alembic в `requirements.txt`:
#
# ```ini
# ...
# alembic
# ```
#
# Выполните в терминале:
# ```cmd
# pip install -r requirements.txt
# ```
#
# ### Инициализация Alembic
#
# В корне проекта (где лежит app/) выполните:
# ```bash
# alembic init alembic
# ```
#
# Структура после выполнения команды:
# ```bash
# alembic/
#     env.py
#     script.py.mako
# alembic.ini
# ```
#
# В alembic.ini сделайте sqlalchemy.url пустым — URL базы будет подтягиваться из .env через settings.DATABASE_URL:
# ```ini
# ...
# # sqlalchemy.url = driver://user:pass@localhost/dbname
# sqlalchemy.url =
# ...
# ```
#
# ### Настройка Alembic для async SQLite
#
# В файле alembic/env.py нужно изменить следующие моменты:
#
# Используйте create_async_engine из sqlalchemy.ext.asyncio вместо обычного create_engine.
# Target metadata: укажите на Base.metadata вашего приложения, чтобы Alembic видел модели, для этого:
#
# Добавьте импорты:
# ```python
# from app.utils.database import Base
# from app.modules.notes.model import Note
# from app.config import settings
# from sqlalchemy.ext.asyncio import create_async_engine
# import asyncio
# ```
#
# Укажите Base.metadata вашего приложения:
# ```python
# ...
# target_metadata = Base.metadata
# ...
# ```
#
# В функции run_migrations_offline() замените:
# ```python
# url = config.get_main_option("sqlalchemy.url")
# ```
# на
# ```python
# # url = config.get_main_option("sqlalchemy.url")
# url = settings.DATABASE_URL
# ```
#
# Содержимое функции run_migrations_online() меняем полностью на:
# ```python
# def run_migrations_online() -> None:
#     connectable = create_async_engine(settings.DATABASE_URL, poolclass=pool.NullPool)
#     async def do_run_migrations():
#         async with connectable.connect() as connection:
#             # Конфигурация Alembic для текущего соединения
#             await connection.run_sync(lambda conn: context.configure(connection=conn, target_metadata=target_metadata))
#             async with connection.begin():
#                 # Запуск миграций
#                 await connection.run_sync(lambda conn: context.run_migrations())
#     asyncio.run(do_run_migrations())
# ```
#
# В файле `alembic.ini` установим формат файла миграции:
# ```ini
# file_template = %%(year)d%%(month).2d%%(day).2d_%%(slug)s
# ```
#
# ## Применение Alembic
#
# ### Фиксируем текущую структуру базы данных (до применения Alembic)
#
# Считаем, что база данных db.sqlite уже имеет созданную ранее таблицу. Чтобы закрепить сущестующую структуру и Alimbic её не удалил,
# нужно один раз выполнить в терминале:
# ```cmd
# alembic stamp head
# ```
# Обращаю ваше внимание, что фиксировать нужно только один раз после того, как установили Alembic и только для случая, если
# у вас существует уже база данных в проекте. Если базы данных нет или она пустая, то команда `alembic stamp head`
# не имеет смысла и её выполнять не нужно.
#
# ## Создание модели User
#
# Создайте каталог для нового модуля: app/modules/auth
#
# Внутри каталога создайте файл model.py:
#
# ```python
# # app/modules/auth/model.py
#
# from sqlalchemy import Column, Integer, String, Boolean, DateTime
# from sqlalchemy.sql import func
# from app.utils.database import Base  # базовый класс Declarative Base
#
#
# class User(Base):
#     """
#     ORM-модель пользователя.
#
#     Отражает таблицу users в базе данных.
#     Используется для:
#     - регистрации и авторизации пользователей
#     - проверки прав доступа (админ/не админ)
#     - хранения основной информации о пользователе
#     """
#
#     __tablename__ = "user"  # имя таблицы в базе данных
#
#     id = Column(
#         Integer,
#         primary_key=True,  # первичный ключ
#         index=True          # индекс для быстрого поиска по id
#     )
#
#     name = Column(
#         String(100),       # имя пользователя (до 100 символов)
#         nullable=True      # поле опциональное
#     )
#
#     login = Column(
#         String(50),        # логин пользователя
#         unique=True,       # уникальный логин
#         nullable=True      # поле опциональное
#     )
#
#     password = Column(
#         String(255),       # хеш пароля
#         nullable=True      # поле опциональное
#     )
#
#     is_admin = Column(
#         Boolean,
#         default=False      # флаг админа по умолчанию False
#     )
#
#     created_at = Column(
#         DateTime(timezone=True),
#         server_default=func.now(),  # дата и время создания записи
#         nullable=False
#     )
# ```
#
# В файле alembic/env.py добавьте импорт модели:
# ```python
# from app.modules.auth.model import User
# ```
#
# ## Создание таблицы в базе данных с помощью создания миграции
#
# В терминале выполните:
# ```cmd
# alembic revision --autogenerate -m "add user"
# ```
#
# В результате в каталоге alembic/versions должен появиться файл с именем, например 20260120_add_user.py
# ```cmd
# alembic/versions/20260120_add_user.py
# ```
#
# Здесь 20260120 - это дата создания файла, у вас будет своя дата.
#
# Для применения миграции и изменения структуры базы данных в терминале выполните:
# ```cmd
# alembic upgrade head
# ```
#
# В базе данных base/db.sqlite должна появиться новая таблица 'user'
#
# ### Справочник всех команд Alembic
#
# Полный справочник команд в файле [alembic.md](alembic.md)
#
# ### Если проблема при создании или применении миграции
#
# #### Вариант 1
#
# В случае проблем работы механизма миграций вы можете удалить файл базы данных base/db.sqlite,
# перезапустить программу.
# ```cmd
# python -m app.main
# ```
# и удалить все файлы из каталога alembic/versions.
# После этого занового инициализировать миграции:
# ```cmd
# alembic stamp head
# ```
# В этом случае создавать миграцию не нужно, т.к. созданная база данных уже будет соответствовать текущей структуре моделей.
#
# Вариант 1 вам подходит, если вы согласны начать с чистой базы данных, т.к. все данные будут удалены.
#
# #### Вариант 2
#
# Удалите запись из таблицы `alembic_version` базы данных, если схема БД фактически соответствует текущим моделям, но Alembic находится в неконсистентном состоянии и считает, что миграции не применены.
#
# Как выполнить:
# - Через SQLite (SQL-консоль)
# - Через DB Browser for SQLite (требуется установить предвариательно)
# - Написать собственный крипт на Python для удаления записи из таблицы.
#
# После удаления записи синхронизируйте состояние Alembic с текущей схемой базы данных:
# ```cmd
# alembic stamp head
# ```
#
# Важно помнить:
# - Структура базы данных не изменяется
# - Удаляется только информация о применённых миграциях
# - Используйте этот способ только если вы уверены, что текущая схема БД корректна
#
# Когда подходит этот вариант
# - миграции применялись вручную
# - база данных редактировалась напрямую
# - Alembic выдаёт ошибки:
#   - `Can't locate revision`
#   - `Target database is not up to date`
#   - `Failed to locate revision identified by`

# %% [markdown]
# # Авторизация
#
# **Регистрация**
#
# Новый пользователь создаёт аккаунт, обычно вводя логин и пароль.
# Сервер проверяет, что логин уникален, хэширует пароль и сохраняет данные в базе вместе с информацией о создании аккаунта и ролью пользователя (обычно обычный пользователь по умолчанию).
# Таким образом сервер **никогда не хранит пароль в открытом виде**, а только его безопасный хэш.
#
# **Авторизация**
#
# Пользователь вводит логин и пароль, сервер сравнивает введённый пароль с хэшем в базе.
# Если данные совпадают, сервер выдаёт специальный токен (например, JWT) с информацией о пользователе и времени действия.
# Клиент использует этот токен для последующих запросов к защищённым ресурсам.
# Сервер проверяет токен, извлекает из него пользователя и роль (админ или нет) и на основе этого решает, к чему разрешён доступ.
#
# ## Схема данных
#
# Создадим схему данных в файле app/modules/auth/schema.py:
#
# ```python
# # app/modules/auth/schema.py
#
# """
# Pydantic-схемы для модуля авторизации.
#
# Назначение схем:
# 1. Валидация входных данных при регистрации и авторизации.
# 2. Описание структуры данных для API (response_model).
# 3. Генерация документации OpenAPI (Swagger).
# """
#
# from pydantic import BaseModel, Field
# from datetime import datetime
#
#
# class UserBase(BaseModel):
#     """
#     Базовая схема пользователя.
#
#     Содержит общие поля:
#     - имя пользователя
#     - логин
#     Используется как родительская схема для создания и ответа API.
#     """
#
#     name: str | None = Field(
#         None,
#         min_length=2,
#         max_length=100,
#         description="Имя пользователя (опционально)"
#     )
#
#     login: str | None = Field(
#         None,
#         min_length=3,
#         max_length=50,
#         description="Логин пользователя (уникальный)"
#     )
#
#
# class UserCreate(UserBase):
#     """
#     Схема для регистрации/создания пользователя.
#
#     Клиент передаёт:
#     - login
#     - password
#     - name (опционально)
#     """
#     password: str = Field(
#         ...,
#         min_length=5,
#         max_length=128,
#         description="Пароль пользователя"
#     )
#
#     is_admin: bool = Field(
#         default=False,
#         description="Флаг администратора (по умолчанию False)"
#     )
#
#
# class UserUpdate(BaseModel):
#     """
#     Схема для обновления пользователя.
#
#     Все поля опциональные:
#     - позволяет обновлять только часть данных
#     """
#     name: str | None = Field(None, min_length=2, max_length=100)
#     login: str | None = Field(None, min_length=3, max_length=50)
#     password: str | None = Field(None, min_length=5, max_length=128)
#     is_admin: bool | None = None
#
#
# class UserResponse(UserBase):
#     """
#     Схема ответа API (response_model) для пользователя.
#
#     Содержит id и флаг администратора.
#     """
#     id: int = Field(..., description="Уникальный идентификатор пользователя")
#     is_admin: bool = Field(False, description="Флаг администратора")
#     created_at: datetime | None = Field(None, description="Дата и время создания записи")
# ```
#
# ## Добавим зависимости для регистрации и авторизации
#
# В файле requirements.txt:
# ```ini
# ...
# passlib
# PyJWT
# python-multipart
# ```
#
# Выполним:
# ```cmd
# pip install -r requirements.txt
# ```
#
# ## Сервисные функции
#
# Чтобы не загромождать файл маршрутов, вынесем методы работы с базой данных в отдельный файл
# app/modules/auth/service.py:
# ```python
# # app/modules/auth/service.py
#
# """
# Сервисный слой для работы с пользователями (User).
#
# Назначение:
# 1. Отделение бизнес-логики от маршрутов (routes)
# 2. Работа с базой данных через SQLAlchemy AsyncSession
# 3. CRUD операции:
#     - создание пользователя
#     - чтение пользователей
#     - обновление пользователя
#     - удаление пользователя
# """
#
# from sqlalchemy.ext.asyncio import AsyncSession
# from sqlalchemy.future import select
# from sqlalchemy.exc import IntegrityError
#
# from app.modules.auth.model import User
# from app.modules.auth.schema import UserCreate, UserUpdate
#
# # ────────────── CREATE ──────────────
# async def create_user_service(user_data: UserCreate, db: AsyncSession) -> User:
#     """
#     Создаёт нового пользователя в базе данных.
#     - Пароль должен быть уже захэширован
#     - Проверяет уникальность логина через БД (IntegrityError)
#     """
#     db_user = User(
#         login=user_data.login,
#         name=user_data.name,
#         password=user_data.password,
#         is_admin=user_data.is_admin
#     )
#     db.add(db_user)
#     try:
#         await db.commit()
#         await db.refresh(db_user)  # Получаем данные после вставки
#     except IntegrityError as e:
#         await db.rollback()
#         raise e
#     return db_user
#
#
# # ────────────── READ ──────────────
# async def read_users_service(db: AsyncSession) -> list[User]:
#     """
#     Возвращает список всех пользователей из базы данных.
#     Используется для админских операций.
#     """
#     result = await db.execute(select(User))
#     return result.scalars().all()
#
#
# async def read_user_service(user_id: int, db: AsyncSession) -> User | None:
#     """
#     Возвращает одного пользователя по ID.
#     Если пользователь не найден, возвращает None.
#     """
#     result = await db.execute(select(User).where(User.id == user_id))
#     return result.scalar_one_or_none()
#
#
# async def read_user_by_login_service(login: str, db: AsyncSession) -> User | None:
#     """
#     Возвращает одного пользователя по логину.
#     Используется при авторизации.
#     """
#     result = await db.execute(select(User).where(User.login == login))
#     return result.scalar_one_or_none()
#
#
# # ────────────── UPDATE ──────────────
# async def update_user_service(user_id: int, user_update: UserUpdate, db: AsyncSession) -> User:
#     """
#     Обновляет данные пользователя.
#     - Пароль должен быть уже захэширован
#     - Проверяет уникальность логина через БД
#     """
#     db_user = await read_user_service(user_id, db)
#     if not db_user:
#         return None
#
#     for key, value in user_update.dict(exclude_unset=True).items():
#         setattr(db_user, key, value)
#
#     try:
#         await db.commit()
#         await db.refresh(db_user)
#     except IntegrityError as e:
#         await db.rollback()
#         raise e
#
#     return db_user
#
#
# # ────────────── DELETE ──────────────
# async def delete_user_service(user_id: int, db: AsyncSession) -> None:
#     """
#     Удаляет пользователя по ID.
#     """
#     db_user = await read_user_service(user_id, db)
#     if not db_user:
#         return None
#
#     await db.delete(db_user)
#     await db.commit()
# ```
#
# ## Утилита для хэширования паролей
#
# Добавим утилиту для хэширования паролей в файле app/utils/security.py:
# ```python
# # app/utils/security.py
#
# from passlib.context import CryptContext
#
# # Создаём контекст для хэширования паролей
# # schemes=["sha256_crypt"] - используем SHA-256 с солью
# # deprecated="auto" - автоматически помечает устаревшие схемы
# pwd_context = CryptContext(schemes=["sha256_crypt"], deprecated="auto")
#
#
# def hash_password(password: str) -> str:
#     """
#     Хэширует пароль.
#
#     :param password: строка пароля пользователя
#     :return: хэшированный пароль в виде строки
#     """
#     return pwd_context.hash(password)
#
#
# def verify_password(plain_password: str, hashed_password: str) -> bool:
#     """
#     Проверяет совпадение пароля с его хэшем.
#
#     :param plain_password: строка пароля пользователя
#     :param hashed_password: хэшированный пароль из базы
#     :return: True если пароль совпадает с хэшем, иначе False
#     """
#     return pwd_context.verify(plain_password, hashed_password)
# ```
#
# ## Добавим параметры авторизации
#
# В файлах .env и .env_example добавьте параметры:
# ```ini
# # Авторизация
# AUTH_SECRET_KEY = 8f3d9a2c7e4b1a6f9d0e5c2b7a4e8f1d6c9b0a3e5f7d2c4b8a1e9
# AUTH_TOKEN_EXPIRE_MINUTES = 525600
# ```
#
# Здесь:
# AUTH_SECRET_KEY - произвольная строка
# AUTH_TOKEN_EXPIRE_MINUTES - количество минут времени жизни токена авторизации (525600 - это один год)
#
# Эти же параметры укажем в congig.py:
# ```python
# # config.py
#
# from pydantic_settings import BaseSettings, SettingsConfigDict
#
# class Settings(BaseSettings):
#
#     LOG_PRINT: str = "1"
#     DATABASE_URL: str
#     AUTH_SECRET_KEY: str
#     AUTH_TOKEN_EXPIRE_MINUTES: int
#
#     model_config = SettingsConfigDict(
#         env_file=".env",
#         extra="ignore"
#     )
#
# settings = Settings()
# ```
#
# ## Маршруты для регистрации и авторизации
#
# Создадим маршруты в файле app/modules/auth/route.py:
#
# ```python
# # app/modules/auth/route.py
#
# """
# Маршруты для регистрации, авторизации и CRUD пользователей.
#
# Используется:
# - регистрация нового пользователя
# - получение JWT токена
# - получение списка пользователей
# - просмотр, обновление и удаление пользователя
# """
#
# from fastapi import APIRouter, Request, Depends, HTTPException, status
# from fastapi.security import OAuth2PasswordRequestForm, OAuth2PasswordBearer
# from typing import List, Optional
# from datetime import datetime, timedelta, timezone
# import jwt  # PyJWT
# from jwt.exceptions import ExpiredSignatureError, InvalidTokenError
# from sqlalchemy.exc import IntegrityError
# from sqlalchemy.ext.asyncio import AsyncSession
#
# from app.modules.auth.schema import UserCreate, UserUpdate, UserResponse
# from app.modules.auth.service import (
#     create_user_service,
#     read_user_by_login_service,
#     read_user_service,
#     read_users_service,
#     update_user_service,
#     delete_user_service
# )
# from app.utils.security import hash_password, verify_password
# from app.config import settings
# from app.utils.database import get_db
#
# router = APIRouter(prefix="/auth", tags=["auth"])
#
# # ────────────── JWT ──────────────
# SECRET_KEY = settings.AUTH_SECRET_KEY
# ACCESS_TOKEN_EXPIRE_MINUTES = settings.AUTH_TOKEN_EXPIRE_MINUTES
# ALGORITHM = "HS256"
# oauth2_scheme = OAuth2PasswordBearer(tokenUrl="/auth/token")
#
#
# def create_access_token(data: dict, expires_delta: Optional[timedelta] = None):
#     """
#     Создаёт JWT токен на основе данных пользователя и времени жизни токена.
#     """
#     to_encode = data.copy()
#     expire = datetime.now(timezone.utc) + (expires_delta or timedelta(minutes=15))
#     to_encode.update({"exp": expire})
#     return jwt.encode(to_encode, SECRET_KEY, algorithm=ALGORITHM)
#
#
# async def get_current_user(token: str = Depends(oauth2_scheme), db: AsyncSession = Depends(get_db)):
#     """
#     Проверяет JWT токен и возвращает пользователя.
#     """
#     try:
#         payload = jwt.decode(token, SECRET_KEY, algorithms=[ALGORITHM])
#         login: str = payload.get("sub")
#         if login is None:
#             raise HTTPException(status_code=status.HTTP_401_UNAUTHORIZED, detail="Invalid token")
#     except ExpiredSignatureError:
#         raise HTTPException(status_code=status.HTTP_401_UNAUTHORIZED, detail="Token expired")
#     except InvalidTokenError:
#         raise HTTPException(status_code=status.HTTP_401_UNAUTHORIZED, detail="Invalid token")
#
#     user = await read_user_by_login_service(login, db)
#     if not user:
#         raise HTTPException(status_code=status.HTTP_404_NOT_FOUND, detail="User not found")
#
#     return user
#
#
# # ────────────── Регистрация ──────────────
# @router.post("/register", response_model=UserResponse, status_code=status.HTTP_201_CREATED)
# async def register_user(user: UserCreate, db: AsyncSession = Depends(get_db)):
#     """
#     Регистрация нового пользователя.
#     - Пароль хэшируется перед сохранением
#     - Флаг администратора по умолчанию False
#     """
#     user.is_admin = False
#     if user.password:
#         user.password = hash_password(user.password)
#
#     try:
#         created_user = await create_user_service(user, db)
#         return created_user
#     except IntegrityError:
#         raise HTTPException(
#             status_code=status.HTTP_400_BAD_REQUEST,
#             detail=f"Пользователь с логином '{user.login}' уже существует"
#         )
#
#
# # ────────────── Авторизация ──────────────
# @router.post("/token")
# async def login_for_access_token(form_data: OAuth2PasswordRequestForm = Depends(), db: AsyncSession = Depends(get_db)):
#     """
#     Авторизация пользователя и получение JWT токена.
#     Вход: username и password
#     Выход: access_token и информация о пользователе
#     """
#     user = await read_user_by_login_service(form_data.username, db)
#     if not user or not verify_password(form_data.password, user.password):
#         raise HTTPException(
#             status_code=status.HTTP_401_UNAUTHORIZED,
#             detail="Incorrect username or password"
#         )
#
#     access_token_expires = timedelta(minutes=ACCESS_TOKEN_EXPIRE_MINUTES)
#     access_token = create_access_token(
#         data={"sub": user.login},
#         expires_delta=access_token_expires
#     )
#
#     return {
#         "access_token": access_token,
#         "token_type": "bearer",
#         "user": user
#     }
#
#
# # ────────────── CRUD USERS ──────────────
#
# @router.get("/users", response_model=List[UserResponse])
# async def get_users(current_user=Depends(get_current_user), db: AsyncSession = Depends(get_db)):
#     """
#     Получение списка всех пользователей (только админ)
#     """
#     if not current_user.is_admin:
#         raise HTTPException(status_code=status.HTTP_403_FORBIDDEN, detail="Access denied")
#     return await read_users_service(db)
#
#
# @router.get("/users/{user_id}", response_model=UserResponse)
# async def get_user_by_id(user_id: int, current_user=Depends(get_current_user), db: AsyncSession = Depends(get_db)):
#     """
#     Получение информации о пользователе по ID.
#     - Админ может получить любого пользователя
#     - Обычный пользователь может получить только себя
#     """
#     user_id = int(user_id)
#
#     if not current_user.is_admin and current_user.id != user_id:
#         raise HTTPException(status_code=status.HTTP_403_FORBIDDEN, detail="Access denied")
#
#     user = await read_user_service(user_id, db)
#     if not user:
#         raise HTTPException(status_code=status.HTTP_404_NOT_FOUND, detail="User not found")
#
#     return user
#
#
# @router.put("/users/{user_id}", response_model=UserResponse)
# async def update_user(user_id: int, user_update: UserUpdate, current_user=Depends(get_current_user), db: AsyncSession = Depends(get_db)):
#     """
#     Обновление пользователя
#     - Админ может редактировать любого пользователя, включая флаг is_admin
#     - Обычный пользователь может редактировать только себя, флаг is_admin нельзя менять
#     """
#     user_id = int(user_id)
#
#     # Проверка доступа
#     if not current_user.is_admin and current_user.id != user_id:
#         raise HTTPException(status_code=status.HTTP_403_FORBIDDEN, detail="Access denied")
#
#     # Обычный пользователь не может менять is_admin
#     if not current_user.is_admin and user_update.is_admin is not None:
#         user_update.is_admin = None
#
#     return await update_user_service(user_id, user_update, db)
#
# @router.delete("/users/{user_id}", status_code=200)
# async def delete_user(user_id: int, current_user=Depends(get_current_user), db: AsyncSession = Depends(get_db)):
#     """
#     Удаление пользователя
#     - Админ может удалить любого
#     - Обычный пользователь может удалить только себя
#     """
#     user_id = int(user_id)
#
#     if not current_user.is_admin and current_user.id != user_id:
#         raise HTTPException(status_code=status.HTTP_403_FORBIDDEN, detail="Нет досутпа")
#
#     db_user = await read_user_service(user_id, db)
#     if not db_user:
#         raise HTTPException(status_code=status.HTTP_404_NOT_FOUND, detail=f"Пользователь {user_id} не найден")
#
#     await delete_user_service(user_id, db)
#     return {"detail": f"Пользователь {user_id} удален успешно"}
# ```
#
# ### Пояснение про current_user = Depends(get_current_user)
#
# `current_user = Depends(get_current_user)` — это зависимость FastAPI, которая извлекает и проверяет текущего аутентифицированного пользователя для каждого HTTP-запроса (по JWT/токену из заголовков), и передаёт в эндпоинт уже валидный объект пользователя; если пользователь не аутентифицирован или токен неверный, выполнение эндпоинта прерывается HTTP-ошибкой (401/403).
#
# Схема выполнения:
#
# ```text
# HTTP REQUEST
#     |
#     |-- Authorization: Bearer <JWT>
#     v
# FastAPI
#     |
#     |--> Depends(get_current_user)
#              |
#              |--> извлечение токена из headers
#              |--> проверка подписи / срока действия
#              |--> получение user_id
#              |--> запрос пользователя из БД
#              |
#              |--> yield / return user
#     |
#     v
# Выполнение эндпоинта
#     |
#     |--> current_user доступен и валиден
#     |
#     v
# RESPONSE → клиенту
#
# (если ошибка на любом шаге → 401 / 403, эндпоинт не выполняется)
# ```
#
# ## Подключение маршрутов в main.py
#
# В файле main.py добавим:
# ```python
# from .modules.auth.route import router as routes_auth
# ...
# app.include_router(routes_auth)
# ```
#
# ## Автоматическое создание админа
#
# Сделаем автоматическое создание первого админа при инициализации базы данных.
# Для этого доработаем файл app/utils/database.py:
# ```python
# from sqlalchemy.future import select
# from app.utils.security import hash_password
# ...
# # Инициализация базы данных
# async def init_db(logger):
#
#     # Создаём таблицы
#     async with engine.begin() as conn:
#         await conn.run_sync(Base.metadata.create_all)
#
#     # Проверяем наличие админа
#     from app.modules.auth.model import User
#     async with AsyncSessionLocal() as session:
#         result = await session.execute(select(User))
#         users = result.scalars().all()
#
#         if not any(u.is_admin for u in users):
#             # Проверяем, есть ли уже логин 'admin'
#             if any(u.login == "admin" for u in users):
#                 admin_user = next(u for u in users if u.login == "admin")
#                 admin_user.is_admin = True
#                 session.add(admin_user)
#                 await session.commit()
#                 await session.refresh(admin_user)
#                 await logger.log_info("db", "Существующий пользователь 'admin' стал администратором")
#             else:
#                 # Создаём первого админа
#                 admin_user = User(
#                     name="Administrator",
#                     login="admin",
#                     password=hash_password("admin"),
#                     is_admin=True
#                 )
#                 session.add(admin_user)
#                 await session.commit()
#                 await session.refresh(admin_user)
#                 await logger.log_info("db", f"Создан первый админ: {admin_user.login}")
# ```
#
# ## Тестирование
#
# Добавим файл app/modules/auth/test.ipunb (код файла возьмите из материалов)
# Выполните тестирование каждого блока.

# %% [markdown]
# # Защита маршрутов
#
# Добавим в модель Note свойство user_id для того, чтобы каждый пользователь редактировал только свои заметки.
# Вторым этапом защитим маргруты так, чтобы пользователь мог редактировать только свои заметки.
#
# ## Добавим в модель Note внешний ключ user_id
#
# Для этого изменим файл app/modules/notes/model.py:
# ```python
# # app/modules/notes/model.py
#
# from sqlalchemy import Column, Integer, String, Text, ForeignKey
# from sqlalchemy.orm import relationship
# from app.utils.database import Base
#
#
# class Note(Base):
#     """
#     ORM-модель заметки.
#
#     Отражает таблицу note в базе данных.
#     Используется для:
#     - создания заметок
#     - чтения данных
#     - обновления и удаления записей
#     """
#
#     __tablename__ = "note"
#
#     id = Column(Integer, primary_key=True, index=True)
#     title = Column(String(100), nullable=False)
#     content = Column(Text, nullable=False)
#     user_id = Column(Integer, ForeignKey("user.id"), nullable=True)
#
#     # Связь с пользователем
#     user = relationship("User", back_populates="notes")
# ```
#
# Так же добавим связь в модель User в файле app/modules/auth/model.py:
# ```python
# # app/modules/auth/model.py
#
# from sqlalchemy import Column, Integer, String, Boolean, DateTime
# from sqlalchemy.sql import func
# from sqlalchemy.orm import relationship
# from app.utils.database import Base
#
#
# class User(Base):
#     """
#     ORM-модель пользователя.
#
#     Отражает таблицу user в базе данных.
#     Используется для:
#     - регистрации и авторизации пользователей
#     - проверки прав доступа (админ/не админ)
#     - хранения основной информации о пользователе
#     """
#
#     __tablename__ = "user"
#
#     id = Column(Integer, primary_key=True, index=True)
#     name = Column(String(100), nullable=True)
#     login = Column(String(50), unique=True, nullable=True)
#     password = Column(String(255), nullable=True)
#     is_admin = Column(Boolean, default=False)
#     created_at = Column(DateTime(timezone=True), server_default=func.now(), nullable=False)
#
#     # Связь с заметками
#     notes = relationship("Note", back_populates="user", cascade="all, delete-orphan")
# ```
#
# ## Создадим и применим миграцию для изменения структуры базы данных
#
# В терминале выполните команду для создания миграции:
# ```cmd
# alembic revision --autogenerate -m "add user_id to note"
# ```
#
# ## Ручное редактирование миграции
#
# Откройте файл миграции из папки alembic/versions и замените код функций:
#
# ```python
# def upgrade() -> None:
#     with op.batch_alter_table("note", recreate="always") as batch_op:
#         batch_op.add_column(
#             sa.Column("user_id", sa.Integer(), nullable=True)
#         )
#         batch_op.create_foreign_key(
#             "fk_note_user_id_user",
#             "user",
#             ["user_id"],
#             ["id"],
#         )
#
# def downgrade() -> None:
#     with op.batch_alter_table("note", recreate="always") as batch_op:
#         batch_op.drop_constraint(
#             "fk_note_user_id_user",
#             type_="foreignkey"
#         )
#         batch_op.drop_column("user_id")
# ```
#
# ## Примените миграцию:
# ```cmd
# alembic upgrade head
# ```
#
# В таблице 'note' должно появиться поле 'user_id'
#
# ## Создание защищенных маршрутов
#
# Создадим новый файл маршрутов app/modules/notes/route_user.py, где каждый пользователь работает со своими заметками:
# ```python
# # app/modules/notes/route_user.py
#
# """
# Маршруты для работы с заметками (CRUD) с логированием.
# Используется база данных через SQLAlchemy (AsyncSession).
#
# ВАЖНО:
# - Все маршруты защищены авторизацией
# - Пользователь работает ТОЛЬКО со своими заметками
# - Доступ к чужим заметкам запрещён
#
# Операции:
# - создание заметки
# - получение списка заметок пользователя
# - получение заметки по id
# - частичное обновление
# - полная замена
# - удаление
# """
#
# from fastapi import APIRouter, HTTPException, status, Request, Depends
# from sqlalchemy.ext.asyncio import AsyncSession
# from sqlalchemy.future import select
#
# from app.modules.notes.schema import Note, NoteCreate, NoteUpdate
# from app.modules.notes.model import Note as NoteModel
# from app.modules.auth.model import User as UserModel
# from app.modules.auth.route import get_current_user
# from app.utils.database import get_db
#
# router = APIRouter(prefix="/notes", tags=["notes"])
#
#
# @router.get(
#     "/",
#     response_model=list[Note],
#     status_code=status.HTTP_200_OK,
#     summary="Получить все заметки пользователя"
# )
# async def get_notes(
#     request: Request,
#     db: AsyncSession = Depends(get_db),
#     current_user: UserModel = Depends(get_current_user)
# ):
#     """
#     GET /notes
#     Возвращает список заметок ТЕКУЩЕГО пользователя.
#     """
#     result = await db.execute(
#         select(NoteModel).where(NoteModel.user_id == current_user.id)
#     )
#     notes = result.scalars().all()
#
#     await request.app.state.log.log_info(
#         "notes",
#         "Получение заметок пользователя",
#         {"user_id": current_user.id, "count": len(notes)}
#     )
#
#     return notes
#
#
# @router.post(
#     "/",
#     response_model=Note,
#     status_code=status.HTTP_201_CREATED,
#     summary="Создать новую заметку"
# )
# async def create_note(
#     request: Request,
#     note: NoteCreate,
#     db: AsyncSession = Depends(get_db),
#     current_user: UserModel = Depends(get_current_user)
# ):
#     """
#     POST /notes
#     Создаёт новую заметку и привязывает её к текущему пользователю.
#     """
#     db_note = NoteModel(
#         title=note.title,
#         content=note.content,
#         user_id=current_user.id
#     )
#
#     db.add(db_note)
#     await db.commit()
#     await db.refresh(db_note)
#
#     await request.app.state.log.log_info(
#         "notes",
#         "Создана новая заметка",
#         {"id": db_note.id, "user_id": current_user.id}
#     )
#
#     return db_note
#
#
# @router.get(
#     "/{note_id}",
#     response_model=Note,
#     status_code=status.HTTP_200_OK,
#     summary="Получить заметку по ID"
# )
# async def get_note(
#     request: Request,
#     note_id: int,
#     db: AsyncSession = Depends(get_db),
#     current_user: UserModel = Depends(get_current_user)
# ):
#     """
#     GET /notes/{id}
#     Получает заметку по id, ТОЛЬКО если она принадлежит пользователю.
#     """
#     result = await db.execute(
#         select(NoteModel).where(
#             NoteModel.id == note_id,
#             NoteModel.user_id == current_user.id
#         )
#     )
#     note = result.scalar_one_or_none()
#
#     if not note:
#         await request.app.state.log.log_error(
#             "notes",
#             f"Доступ запрещён или заметка не найдена (id={note_id})"
#         )
#         raise HTTPException(
#             status_code=status.HTTP_404_NOT_FOUND,
#             detail="Заметка не найдена"
#         )
#
#     await request.app.state.log.log_info(
#         "notes",
#         "Получена заметка",
#         {"id": note_id, "user_id": current_user.id}
#     )
#
#     return note
#
#
# @router.patch(
#     "/{note_id}",
#     response_model=Note,
#     status_code=status.HTTP_200_OK,
#     summary="Частично обновить заметку"
# )
# async def patch_note(
#     request: Request,
#     note_id: int,
#     data: NoteUpdate,
#     db: AsyncSession = Depends(get_db),
#     current_user: UserModel = Depends(get_current_user)
# ):
#     """
#     PATCH /notes/{id}
#     Частичное обновление заметки пользователя.
#     """
#     result = await db.execute(
#         select(NoteModel).where(
#             NoteModel.id == note_id,
#             NoteModel.user_id == current_user.id
#         )
#     )
#     note = result.scalar_one_or_none()
#
#     if not note:
#         await request.app.state.log.log_error(
#             "notes",
#             f"Попытка обновления чужой или несуществующей заметки (id={note_id})"
#         )
#         raise HTTPException(
#             status_code=status.HTTP_404_NOT_FOUND,
#             detail="Заметка не найдена"
#         )
#
#     if data.title is not None:
#         note.title = data.title
#     if data.content is not None:
#         note.content = data.content
#
#     await db.commit()
#     await db.refresh(note)
#
#     await request.app.state.log.log_info(
#         "notes",
#         "Обновлена заметка",
#         {"id": note_id, "user_id": current_user.id}
#     )
#
#     return note
#
#
# @router.put(
#     "/{note_id}",
#     response_model=Note,
#     status_code=status.HTTP_200_OK,
#     summary="Полностью заменить заметку"
# )
# async def put_note(
#     request: Request,
#     note_id: int,
#     data: NoteCreate,
#     db: AsyncSession = Depends(get_db),
#     current_user: UserModel = Depends(get_current_user)
# ):
#     """
#     PUT /notes/{id}
#     Полная замена заметки пользователя.
#     """
#     result = await db.execute(
#         select(NoteModel).where(
#             NoteModel.id == note_id,
#             NoteModel.user_id == current_user.id
#         )
#     )
#     note = result.scalar_one_or_none()
#
#     if not note:
#         await request.app.state.log.log_error(
#             "notes",
#             f"Попытка замены чужой или несуществующей заметки (id={note_id})"
#         )
#         raise HTTPException(
#             status_code=status.HTTP_404_NOT_FOUND,
#             detail="Заметка не найдена"
#         )
#
#     note.title = data.title
#     note.content = data.content
#
#     await db.commit()
#     await db.refresh(note)
#
#     await request.app.state.log.log_info(
#         "notes",
#         "Полностью заменена заметка",
#         {"id": note_id, "user_id": current_user.id}
#     )
#
#     return note
#
#
# @router.delete(
#     "/{note_id}",
#     status_code=status.HTTP_204_NO_CONTENT,
#     summary="Удалить заметку"
# )
# async def delete_note(
#     request: Request,
#     note_id: int,
#     db: AsyncSession = Depends(get_db),
#     current_user: UserModel = Depends(get_current_user)
# ):
#     """
#     DELETE /notes/{id}
#     Удаляет заметку пользователя.
#     """
#     result = await db.execute(
#         select(NoteModel).where(
#             NoteModel.id == note_id,
#             NoteModel.user_id == current_user.id
#         )
#     )
#     note = result.scalar_one_or_none()
#
#     if not note:
#         await request.app.state.log.log_error(
#             "notes",
#             f"Попытка удаления чужой или несуществующей заметки (id={note_id})"
#         )
#         raise HTTPException(
#             status_code=status.HTTP_404_NOT_FOUND,
#             detail="Заметка не найдена"
#         )
#
#     await db.delete(note)
#     await db.commit()
#
#     await request.app.state.log.log_info(
#         "notes",
#         "Удалена заметка",
#         {"id": note_id, "user_id": current_user.id}
#     )
#
#     return None
# ```
#
# ## Подключение маршрутов в файле main.py
#
# В файле main.py измените строку импорта с:
# ```python
# from .modules.notes.route import router as routes_notes
# ```
# на
# ```python
# from .modules.notes.route_user import router as routes_notes
# ```
#
# ## Тестирование
#
# Создайте файл app/modules/notes/test_user.ipynb. Файл скопируйте из материалов.
#
# Выполните тестирование по шагам.

# %% [markdown]
# # Подключение LLM
#
# ## Настройки LLM
#
# В файлах .env и .env_example создадим настройки:
# ```ini
# # LLM
# LLM_BASE_URL = https://api.openai.com/v1/responses
# LLM_MODEL = gpt-4o-mini
# LLM_API_KEY = ваш_api_key
# ```
#
# Здесь:
# LLM_BASE_URL - базовый URL API модели LLM
# LLM_MODEL - название модели
# LLM_API_KEY - токен
#
# Добавим их так же в файле config.py:
# ```python
# # config.py
#
# from pydantic_settings import BaseSettings, SettingsConfigDict
#
# class Settings(BaseSettings):
#
#     LOG_PRINT: str = "1"
#     DATABASE_URL: str
#     AUTH_SECRET_KEY: str
#     AUTH_TOKEN_EXPIRE_MINUTES: int
#     LLM_BASE_URL: str
#     LLM_MODEL: str
#     LLM_API_KEY: str
#
#     model_config = SettingsConfigDict(
#         env_file=".env",
#         extra="ignore"
#     )
#
# settings = Settings()
# ```
#
# ## Установим библиотеку для асинхронных запросов
#
# В файле requirements.txt добавим:
# ```ini
# ...
# httpx
# ```
#
# Установим:
# ```cmd
# pip install -r requirements.txt
# ```
#
# ## Создадим сервисную функцию обращения к LLM
#
# Создайте каталог модуля app/modules/gpt.
#
# Создайте файл app/modules/gpt/service.py:
# ```python
# # app/modules/gpt/service.py
#
# """
# Сервисный слой для обращения к LLM (GPT-модели) через Responses API.
#
# Назначение:
# 1. Асинхронные запросы к внешнему API LLM
# 2. Отделение бизнес-логики от маршрутов (routes)
# 3. Возврат текста модели в стандартизированном виде
#
# Использование:
#     from app.modules.gpt.service import call_gpt
#     answer = await call_gpt("Привет, расскажи стих")
# """
#
# import httpx
# from app.config import settings
#
# # Настройки LLM берём из config.py
# LLM_BASE_URL = getattr(settings, "LLM_BASE_URL", "https://api.openai.com/v1/responses")
# LLM_MODEL = getattr(settings, "LLM_MODEL", "gpt-4o-mini")
# LLM_API_KEY = getattr(settings, "LLM_API_KEY", "")
#
#
# async def call_gpt(prompt: str, temperature: float = 0.7, max_tokens: int = 300) -> str:
#     """
#     Асинхронный вызов GPT-модели через Responses API.
#
#     Параметры:
#     - prompt: str — текст запроса от пользователя
#     - temperature: float — креативность ответа (0–2)
#     - max_tokens: int — максимальное количество токенов в ответе
#
#     Возвращает:
#     - str: текст ответа модели
#
#     Исключения:
#     - RuntimeError: при ошибке LLM API или некорректном формате ответа
#     """
#     headers = {
#         "Authorization": f"Bearer {LLM_API_KEY}",
#         "Content-Type": "application/json"
#     }
#
#     payload = {
#         "model": LLM_MODEL,
#         "input": prompt,            # Responses API теперь использует 'input', а не 'messages'
#         "temperature": temperature,
#         "max_output_tokens": max_tokens
#     }
#
#     async with httpx.AsyncClient(timeout=30) as client:
#         resp = await client.post(LLM_BASE_URL, headers=headers, json=payload)
#
#         if resp.status_code != 200:
#             raise RuntimeError(f"Ошибка при вызове LLM: LLM API error: {resp.status_code}, {resp.text}")
#
#         data = resp.json()
#         try:
#             # Извлекаем текст ответа из структуры Responses API
#             answer = data["output"][0]["content"][0]["text"]
#         except (KeyError, IndexError, TypeError):
#             raise RuntimeError(f"Unexpected LLM response format: {data}")
#
#         return answer
# ```
#
# ## Создание схемы данных
#
# Создайте файл app/modules/gpt/schema.py:
# ```python
# # app/modules/gpt/schema.py
#
# """
# Pydantic-схемы для модуля GPT.
#
# Назначение:
# 1. Валидация данных входящих запросов к LLM
# 2. Описание структуры ответа от LLM
# 3. Генерация документации OpenAPI (Swagger)
# """
#
# from pydantic import BaseModel, Field
#
# class GPTRequest(BaseModel):
#     """
#     Схема запроса к GPT-модели.
#     """
#     prompt: str = Field(..., description="Текстовый запрос для модели GPT")
#     temperature: float = Field(0.7, ge=0, le=1, description="Степень креативности")
#     max_tokens: int = Field(300, ge=1, le=2048, description="Максимальное количество токенов в ответе")
#
#
# class GPTResponse(BaseModel):
#     """
#     Схема ответа от GPT-модели.
#     """
#     answer: str = Field(..., description="Ответ модели GPT")
# ```
#
# ## Создадим файл маршрутов
#
# Создайте файл app/modules/gpt/route.py:
# ```python
# # app/modules/gpt/route.py
#
# """
# Маршруты для работы с LLM (GPT-модели).
#
# Назначение:
# 1. Приём POST-запросов с текстом prompt
# 2. Проверка авторизации пользователя
# 3. Асинхронный вызов GPT через service.py
# """
#
# from fastapi import APIRouter, HTTPException, status, Depends
# from app.modules.gpt.schema import GPTRequest, GPTResponse
# from app.modules.gpt.service import call_gpt
# from app.modules.auth.route import get_current_user  # проверка авторизации
#
# router = APIRouter(prefix="/gpt", tags=["gpt"])
#
# @router.post("/", response_model=GPTResponse, status_code=status.HTTP_200_OK)
# async def gpt_endpoint(request: GPTRequest, current_user=Depends(get_current_user)):
#     """
#     POST /gpt
#     Асинхронно вызывает GPT-модель и возвращает ответ.
#     Требует авторизации пользователя.
#     """
#     try:
#         answer = await call_gpt(
#             prompt=request.prompt,
#             temperature=request.temperature,
#             max_tokens=request.max_tokens
#         )
#         return {"answer": answer}
#     except Exception as e:
#         raise HTTPException(
#             status_code=status.HTTP_500_INTERNAL_SERVER_ERROR,
#             detail=f"Ошибка при вызове LLM: {str(e)}"
#         )
# ```
#
# ## Подключение маршрутов в файле main.py
#
# В файле main.py добавьте:
# ```python
# from .modules.gpt.route import router as routes_gpt
# ...python
# app.include_router(routes_gpt)
# ```
#
# ## Тестирование
#
# Создайте файл app/modules/gpt/test.ipynb. Файл скопируйте из материалов.
#
# Выполните тестирование по шагам.

# %% [markdown]
# № Промпт для CRUD
#
# Сделаем отдельный модуль, который сможет слушать основой для разработки личного помощьника.
# Личный помощник будет в режиме диалога (без использования какого-либо меню)
# взаимодействовать с базой данных, самостоятельно сохранять новые заметки и
# искать в базе данных существующие заметки.
#
# Напишем промпт, который будет генерировать SQL-запросы для ввзаимодействия с базой данных,
# а API будет выполнять эти запросы, возвращая результат пользователю.
#
# ## Создание модуля
#
# Создадим модуль со знакомой нам структурой:
# ```cmd
# app/modules/gpt_crud/
# ├── __init__.py
# ├── schema.py       # Pydantic-схемы запроса/ответа
# ├── service.py      # Сервисный слой: читает промпт и вызывает LLM
# ├── route.py        # FastAPI маршруты, авторизация + вызов LLM
# ```
#
# Создайте каталог app/modules/gpt_crud
#
# ## Создание схемы обмена данными
#
# Создайте файл app/modules/gpt_crud/schema.py:
# ```python
# # app/modules/gpt_crud/schema.py
#
# """
# Схемы данных для модуля gpt_crud.
#
# Назначение:
# 1. Входные данные от пользователя (текстовая команда)
# 2. Выходные данные с SQL-запросом и/или результатом
# """
#
# from pydantic import BaseModel, Field
#
#
# class GPTCRUDRequest(BaseModel):
#     """
#     Схема запроса к GPT для генерации SQL.
#
#     Пример:
#         prompt: "Покажи все заметки пользователя user_test"
#     """
#     prompt: str = Field(..., description="Команда от пользователя для генерации SQL")
#
#
# class GPTCRUDResponse(BaseModel):
#     """
#     Схема ответа от GPT.
#
#     Содержит:
#     - сгенерированный SQL
#     - необязательный результат запроса к базе
#     """
#     sql: str
#     rows: list[dict] | None = None
#     message: str | None = None
# ```
#
# ## Сохдание сервисного файла
#
# Создайте файл app/modules/gpt_crud/service.py:
# ```python
# # app/modules/gpt_crud/service.py
#
# """
# Сервисный слой для GPT CRUD с учётом текущего пользователя.
#
# Назначение:
# 1. Асинхронное чтение базового промпта из файла base/crud.md при каждом обращении
# 2. Генерация SQL-запросов на основе команды пользователя с учётом user_id
# 3. Опциональное выполнение SQL-запроса через SQLAlchemy AsyncSession
# 4. Поддержка поиска по корням слов через LIKE '%слово%'
# 5. Обработка SELECT и не-SELECT запросов корректно
# 6. Логирование всех шагов через app.state.log
# """
#
# import aiofiles
# import httpx
# import os
# from app.config import settings
# from sqlalchemy.ext.asyncio import AsyncSession
# from sqlalchemy import text
# from typing import List, Dict
# from fastapi import Request
#
# # ────────────── LLM настройки ──────────────
# LLM_BASE_URL = getattr(settings, "LLM_BASE_URL", "https://api.openai.com/v1/responses")
# LLM_MODEL = getattr(settings, "LLM_MODEL", "gpt-4o-mini")
# LLM_API_KEY = getattr(settings, "LLM_API_KEY", "")
#
# # ────────────── Путь к файлу с базовым промптом ──────────────
# CRUD_PROMPT_FILE = "base/crud.md"
#
# # ────────────── Асинхронное чтение промпта ──────────────
# async def read_prompt() -> str:
#     """
#     Асинхронное чтение промпта из файла base/crud.md при каждом вызове.
#     Если файл не найден — возвращается дефолтный промпт.
#     """
#     if os.path.exists(CRUD_PROMPT_FILE):
#         async with aiofiles.open(CRUD_PROMPT_FILE, mode="r", encoding="utf-8") as f:
#             return await f.read()
#     return "You are a SQL generator for notes app. Generate CRUD SQL queries based on user request."
#
#
# # ────────────── Вызов LLM с user_id ──────────────
# async def call_gpt(
#     user_request: str,
#     user_id: int,
#     request: Request,
#     temperature: float = 0.7,
#     max_tokens: int = 300
# ) -> str:
#     """
#     Асинхронный вызов GPT для генерации SQL с учётом user_id.
#     Promt читается при каждом вызове.
#     Логирование всех шагов через app.state.log
#     """
#     log = request.app.state.log
#
#     # ────────────── Логируем получение запроса ──────────────
#     await log.log_info(target="GPT CRUD", message=f"Получен пользовательский запрос: {user_request}")
#     await log.log_info(target="GPT CRUD", message=f"Определён user_id: {user_id}")
#
#     # ────────────── Чтение базового промпта ──────────────
#     base_prompt = await read_prompt()
#     await log.log_info(target="GPT CRUD", message=f"Прочитан базовый промпт (первые 200 символов): {base_prompt[:200]}")
#
#     # ────────────── Формируем полный промпт для LLM ──────────────
#     full_prompt = f"""
# {base_prompt}
#
# User ID: {user_id}
# User request: {user_request}
#
# Rules:
# - Все SQL-запросы должны фильтровать записи по User ID.
# - Для поиска используем SQL LIKE %слово% для каждого корня слова из запроса.
# - Генерируем SQL только для текущего пользователя.
# - CRUD операции: CREATE, READ, UPDATE, DELETE.
# - Для UPDATE/DELETE сначала ищем note_id через LIKE-поиск.
# - Возвращаем только SQL без объяснений.
# """
#
#     await log.log_info(target="GPT CRUD", message=f"Формирование запроса к LLM с учётом user_id")
#
#     headers = {
#         "Authorization": f"Bearer {LLM_API_KEY}",
#         "Content-Type": "application/json"
#     }
#
#     payload = {
#         "model": LLM_MODEL,
#         "input": full_prompt,
#         "temperature": temperature,
#         "max_output_tokens": max_tokens
#     }
#
#     # ────────────── Отправка запроса к LLM ──────────────
#     async with httpx.AsyncClient(timeout=60) as client:
#         resp = await client.post(LLM_BASE_URL, headers=headers, json=payload)
#         if resp.status_code != 200:
#             await log.log_error(target="GPT CRUD", message=f"Ошибка LLM API: {resp.status_code}, {resp.text}")
#             raise RuntimeError(f"LLM API error: {resp.status_code}, {resp.text}")
#
#         data = resp.json()
#         try:
#             # структура ответа Responses API
#             sql_query = data["output"][0]["content"][0]["text"]
#         except (KeyError, IndexError, TypeError):
#             await log.log_error(target="GPT CRUD", message=f"Неверный формат ответа LLM: {data}")
#             raise RuntimeError(f"Unexpected LLM response format: {data}")
#
#     await log.log_info(target="GPT CRUD", message=f"Сгенерирован SQL-запрос:\n{sql_query}")
#     return sql_query.strip()
#
#
# async def execute_sql(sql: str, db: AsyncSession, request: Request) -> dict:
#     """
#     Выполнение SQL-запроса через SQLAlchemy AsyncSession.
#
#     Возвращает:
#     - SELECT: sql, title, description, rows
#     - INSERT/UPDATE/DELETE: sql, message
#     """
#
#     log = request.app.state.log
#
#     # Логируем оригинальный SQL от GPT
#     await log.log_info(target="GPT CRUD", message=f"SQL от GPT (raw): {sql}")
#
#     # 1. Убираем Markdown и лишние переносы
#     cleaned_sql = (
#         sql
#         .replace("```sql", "")
#         .replace("```", "")
#         .replace("\n", " ")
#         .strip()
#     )
#     cleaned_sql = " ".join(cleaned_sql.split())
#
#     # 2. Берём только первый SQL-запрос (до первого ;)
#     if ";" in cleaned_sql:
#         first_sql = cleaned_sql.split(";", 1)[0].strip() + ";"
#     else:
#         first_sql = cleaned_sql
#
#     await log.log_info(target="GPT CRUD", message=f"SQL после очистки: {first_sql}")
#
#     # 3. Определяем тип запроса
#     sql_type = first_sql.split()[0].upper()
#
#     try:
#         # 4. SELECT
#         if sql_type == "SELECT":
#             result = await db.execute(text(first_sql))
#             rows = result.mappings().all()
#             await log.log_info(target="GPT CRUD", message=f"Найдено заметок: {len(rows)}")
#             return {
#                 "sql": first_sql,
#                 "rows": rows,
#             }
#
#         # 5. INSERT/UPDATE/DELETE
#         await db.execute(text(first_sql))
#         await db.commit()
#         message = {
#             "INSERT": "Заметка добавлена",
#             "UPDATE": "Заметка обновлена",
#             "DELETE": "Заметка удалена"
#         }.get(sql_type, "Запрос выполнен")
#
#         await log.log_info(target="GPT CRUD", message=f"{sql_type}: выполнено успешно")
#         return {
#             "sql": first_sql,
#             "message": message
#         }
#
#     except Exception as e:
#         await db.rollback()
#         await log.log_error(target="GPT CRUD", message=f"Ошибка при выполнении SQL: {str(e)}")
#         raise
# ```
#
# ## Создание файла маршрутов
#
# Создайте файл app/modules/gpt_crud/route.py:
# ```python
# # app/modules/gpt_crud/route.py
#
# """
# Маршруты GPT CRUD для заметок.
#
# Назначение:
# 1. Получение запроса пользователя и генерация SQL через LLM
# 2. Асинхронное выполнение SQL-запросов через базу данных
# 3. Защита маршрутов авторизацией пользователя
# 4. Возврат результата пользователю в JSON формате
# """
#
# from fastapi import APIRouter, Depends, HTTPException, status, Request
# from sqlalchemy.ext.asyncio import AsyncSession
#
# from app.modules.gpt_crud.service import call_gpt, execute_sql
# from app.utils.database import get_db
# from app.modules.auth.route import get_current_user
# from app.modules.gpt_crud.schema import GPTCRUDRequest, GPTCRUDResponse
#
# router = APIRouter(prefix="/gpt_crud", tags=["GPT CRUD"])
#
# @router.post("/", response_model=GPTCRUDResponse, status_code=status.HTTP_200_OK)
# async def gpt_crud_endpoint(
#     request: Request,
#     user_request: GPTCRUDRequest,
#     current_user=Depends(get_current_user),
#     db: AsyncSession = Depends(get_db)
# ):
#     """
#     POST /gpt_crud
#     Генерирует SQL-запрос на основе пользовательского запроса через LLM
#     и выполняет его в базе данных, возвращая результат.
#
#     Аргументы:
#     - user_request: GPTCRUDRequest — текст запроса от пользователя
#     - current_user: текущий авторизованный пользователь
#     - db: асинхронная сессия SQLAlchemy
#
#     Особенности:
#     - Пользователь должен быть авторизован
#     - В prompt передаётся запрос типа:
#         "Запомни тему вебинара 'Тема вебинара о FastAPI'"
#         "Сохрани контакты менеджера по созданию сайта"
#         "Напомни что я должен был сделать к пятнице"
#         "Напомни контакты менеджера по сайту"
#     - SQL-запрос формируется с учётом user_id
#     """
#     try:
#         # 1. Генерация SQL-запроса через GPT с учётом user_id
#         sql_query = await call_gpt(user_request.prompt, user_id=current_user.id, request=request)
#
#         # 2. Выполнение SQL в базе
#         results = await execute_sql(sql_query, db, request=request)
#
#         # 3. Возврат ответа
#         return GPTCRUDResponse(
#             sql=results.get("sql"),
#             rows=results.get("rows"),
#             message=results.get("message")
#         )
#
#     except Exception as e:
#         # Возвращаем понятный detail пользователю
#         raise HTTPException(status_code=500, detail=f"Ошибка при вызове GPT CRUD: {str(e)}")
# ```
#
# ## Подключение маршрутов в файле main.py
#
# В файле main.py добавьте:
# ```python
# from .modules.gpt_crud.route import router as routes_gpt_crud
# ...
# app.include_router(routes_gpt_crud)
# ```
#
# ## Промпт
#
# В файл base/crud.md поместите промпт:
# ```md
# Ты — асинхронный SQL-генератор для приложения заметок. Твоя задача:
#
# 1. На основе пользовательского запроса на естественном языке генерировать корректные SQL-запросы.
#
# 2. Пользовательский запрос может содержать следующие действия:
#    - Создать заметку: "Запомни тему вебинара 'Создание приложений на FastAPI'" или "Сохрани контакты менеджера по сайту"
#    - Показать все заметки текущего пользователя: "Покажи мои заметки"
#    - Найти заметку по тексту: "Напомни что я должен был сделать к пятнице" или "Напомни контакты менеджера по сайту"
#    - Удалить заметку: "Удалить заметку 'текст заметки'" или "Удалить заметку 3"
#    - Обновить заметку: "Поменяй заметку 'старый текст' на 'новый текст'"
#
# 3. Все запросы должны учитывать текущего пользователя через user_id:
#    - Для выборки заметок добавляй WHERE user_id = {user_id}
#    - Для создания заметки указывай user_id = {user_id}
#
# 4. Для поиска по тексту:
#    - Разбивай текст на отдельные слова или цифры
#    - Из каждого слова бери корень (без склонений)
#    - Генерируй SQL вида:
#      WHERE content LIKE '%слово1%' OR content LIKE '%слово2%' ...
#    - Поиск должен быть только в заметках данного пользователя (user_id)
#
# 5. Для создания заметки:
#    - Генерируй INSERT INTO note (title, content, user_id) VALUES (...)
#    - title — короткий заголовок заметки (первые несколько слов, смысловой фрагмент, без повторения полного текста)
#    - content — полный текст заметки, который хочет сохранить пользователь (но убери из него глаголы "запомни", "сохрани" и т.д.)
#
# 6. Для удаления заметки:
#    - Сначала ищи note_id через LIKE по тексту
#    - Затем DELETE FROM note WHERE id = <note_id> AND user_id = {user_id}
#
# 7. Для редактирования заметки:
#    - Сначала ищи note_id через LIKE по старому тексту
#    - Затем UPDATE note SET content = <новый текст> WHERE id = <note_id> AND user_id = {user_id}
#
# 8. Всегда генерируй полностью рабочий SQL, который можно выполнить в базе SQLite с таблицей note:
#    - id (PK, INTEGER)
#    - title (TEXT)
#    - content (TEXT)
#    - user_id (INTEGER)
#
# 9. Отдавай только SQL в ответ, никаких комментариев и пояснений.
#
# 10. Если запрос пользователя двусмысленный — генерируй несколько SQL через точку с запятой.
#
# 11. Примеры пользовательских запросов и SQL:
#
# - "Покажи все мои заметки"
# SELECT * FROM note WHERE user_id = {user_id};
#
# "Напомни что я должен был сделать к пятнице
# SELECT * FROM note
# WHERE user_id = {user_id}
#   AND (content LIKE '%должен%' OR content LIKE '%пятница%');
#
# "Запомни тему вебинара 'Создание приложений на FastAPI с примерами'
# INSERT INTO note (title, content, user_id)
# VALUES ('Тема вебинара', 'Создание приложений на FastAPI с примерами', {user_id});
#
# "Удалить заметку 'Купить молоко'
# SELECT id FROM note
# WHERE user_id = {user_id}
#   AND content LIKE '%Купить%'
#   AND content LIKE '%молоко%';
# DELETE FROM note
# WHERE id = <note_id>
#   AND user_id = {user_id};
#
# "Поменяй заметку 'Купить молоко' на 'Купить хлеб'
# SELECT id FROM note
# WHERE user_id = {user_id}
#   AND content LIKE '%Купить%'
#   AND content LIKE '%молоко%';
# UPDATE note
# SET content = 'Купить хлеб'
# WHERE id = <note_id>
#   AND user_id = {user_id};
# ```
#
# ## Тестирование
#
# Создайте файл app/modules/gpt_crud/test.ipynb. Файл скопируйте из материалов.
#
# Выполните тестирование по шагам.
