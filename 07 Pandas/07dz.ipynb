# %%
import pandas as pd

# %% [markdown]
# ## Задание 1
#
# ---
#
# Загрузите таблицу в переменную `df` по указанному пути ('/content/sample_data/california_housing_train.csv'). Выведите инофрмацию по столбцам:
# * Выведите последние 5 строк
# * Выведите размер таблицы
# * Выведите каждую 2 строку.

# %%
# Решение
df = pd.read_csv('/content/sample_data/california_housing_train.csv')
display(df)
display(df.tail(5))
display(df.shape)
display(df[::2])
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -114.31     34.19                15.0       5612.0          1283.0
# 1        -114.47     34.40                19.0       7650.0          1901.0
# 2        -114.56     33.69                17.0        720.0           174.0
# 3        -114.57     33.64                14.0       1501.0           337.0
# 4        -114.57     33.57                20.0       1454.0           326.0
# ...          ...       ...                 ...          ...             ...
# 16995    -124.26     40.58                52.0       2217.0           394.0
# 16996    -124.27     40.69                36.0       2349.0           528.0
# 16997    -124.30     41.84                17.0       2677.0           531.0
# 16998    -124.30     41.80                19.0       2672.0           552.0
# 16999    -124.35     40.54                52.0       1820.0           300.0
#
# ...

# %%
df.shape
# Out:
# (17000, 9)

# %% [markdown]
# ## Задание 2
#
# ---
# Удалите столбцы из загруженной таблице выше, начиная с `'total_rooms'` и до конца.
#
# Должны остаться первые 3 столбца:
# ![image.png](data:image/png;base64,...)

# %%
# Решение
col_index = df.columns.get_loc("total_rooms")
col_names = df.columns[col_index:]
df1 = df.drop(col_names, axis=1)
df1
# Out:
#        longitude  latitude  housing_median_age
# 0        -114.31     34.19                15.0
# 1        -114.47     34.40                19.0
# 2        -114.56     33.69                17.0
# 3        -114.57     33.64                14.0
# 4        -114.57     33.57                20.0
# ...          ...       ...                 ...
# 16995    -124.26     40.58                52.0
# 16996    -124.27     40.69                36.0
# 16997    -124.30     41.84                17.0
# 16998    -124.30     41.80                19.0
# 16999    -124.35     40.54                52.0
#
# [17000 rows x 3 columns]

# %% [markdown]
# ## Задание 3
#
# ---
#
# * Создай таблицу товаров из магазина электроники, назовите её `df3`. Должно быть 5 строк и 3 столбца: `['Наименование товара', 'Цена', 'Остаток']`.\
# `shape(5, 3)`
# * После того, как создали таблицу добавьте ещё одну строку с умной колонкой(Алиса, Сири..).\
#  `shape(6, 3)`
#
# Результат выведите на экран.

# %%
# Решение
columns = ['Наименование товара', 'Цена', 'Остаток']
data = [
    ["Монитор", 13500.0, 12],
    ["Наушники", 3100.0, 23],
    ["Пылесос", 5200.0, 7],
    ["Утюг", 2100.0, 43],
    ["Стиральная машина", 23700.0, 3]
]

df3 = pd.DataFrame(data=data, columns=columns)

# display(df3)
# print(df3.last_valid_index())
# df3.drop(1, inplace=True)
# display(df3)
# print(df3.last_valid_index())

df3.loc[df3.last_valid_index() + 1] = ["Алиса", 777000, 1000]
df3
# Out:
#   Наименование товара      Цена  Остаток
# 0             Монитор   13500.0       12
# 1            Наушники    3100.0       23
# 2             Пылесос    5200.0        7
# 3                Утюг    2100.0       43
# 4   Стиральная машина   23700.0        3
# 5               Алиса  777000.0     1000

# %% [markdown]
# ## Задание 4
#
# ---
#
# Отсортируйте получившуюся таблицу `df3`, по столбцу "цена". При этом индексы должны идти по порядку. (По возрастанию)

# %%
# Решение
df3 = df3.sort_values("Цена")
df3 = df3.reset_index()
df3 = df3.drop("index", axis=1)
df3
# Out:
#   Наименование товара      Цена  Остаток
# 0                Утюг    2100.0       43
# 1            Наушники    3100.0       23
# 2             Пылесос    5200.0        7
# 3             Монитор   13500.0       12
# 4   Стиральная машина   23700.0        3
# 5               Алиса  777000.0     1000

# %% [markdown]
# ## Задание 5
#
# ---

# %% [markdown]
# * Сохраните получившуюся таблицу в excel формате.
# * Загрузите получившийся результат и выведите на экран.

# %%
# Решение
df3.to_excel("/content/sample_data/elecronika.xlsx")
df4 = pd.read_excel("/content/sample_data/elecronika.xlsx", index_col=0)
display(df4)
# Out:
#   Наименование товара    Цена  Остаток
# 0                Утюг    2100       43
# 1            Наушники    3100       23
# 2             Пылесос    5200        7
# 3             Монитор   13500       12
# 4   Стиральная машина   23700        3
# 5               Алиса  777000     1000
