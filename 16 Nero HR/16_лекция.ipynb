# %% [markdown]
# # Нейро-HR: проведение собеседований
# ![Neuro-HR.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# # Библиотеки. Функции. Предобработка данных

# %%
#@title Установка необходимых библиотек
# !pip install -q openai langchain langchain_community \
langchain_openai langchain_core faiss-cpu \
rarfile PyPDF2
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.5/2.5 MB 18.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 65.4/65.4 kB 1.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 438.1/438.1 kB 20.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 31.3/31.3 MB 25.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 232.6/232.6 kB 10.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.0/363.0 kB 14.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.4/44.4 kB 1.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.9/50.9 kB 2.1 MB/s eta 0:00:00

# %%
#@title Импорт библиотек, активация ключей, папки, глобальные переменные

from langchain.text_splitter import MarkdownHeaderTextSplitter
from langchain_core.output_parsers import JsonOutputParser
from langchain_openai import OpenAIEmbeddings, ChatOpenAI
from langchain_core.pydantic_v1 import BaseModel, Field
from langchain_community.vectorstores import FAISS
from langchain.docstore.document import Document
from langchain.prompts import PromptTemplate


from io import BytesIO
import aiohttp
from google.colab import userdata, drive
from PyPDF2 import PdfReader
from datetime import datetime
import requests
from urllib.parse import urlencode
import textwrap
import rarfile
import openai
import gdown
import json
import time
import os
import re

# Подключаем ГуглДиск для работы с файлами
drive.mount('/content/drive')
# Формируем основной путь
path = '/content/drive/MyDrive/data/hr/'
# Формирование дополнительных путей
path_vacancies_pdf = f'{path}vacancies_pdf/'
path_vacancies_json = f'{path}vacancies_json/'
path_resumes_pdf = f'{path}resumes_pdf/'
path_resumes_json = f'{path}resumeses_json/'
path_db_faiss = f'{path}db_faiss/'
path_add_data = f'{path}add_data/'

folders = [path, path_vacancies_pdf, path_vacancies_json, path_resumes_pdf,
           path_resumes_json, path_db_faiss, path_add_data ]
# Создание необходимых папок на ГуглДиске: '/data/hr/...'
for folder in folders:
    os.makedirs(folder, exist_ok=True)

# Установка API-ключа OpenAI в качестве переменной среды
os.environ["OPENAI_API_KEY"] = userdata.get("OPENAI_API_KEY")

# Cоздание или очистка файла логов, если файл уже есть
open(os.path.join(path, '_log.txt'), 'w').close()
# Out:
# /usr/local/lib/python3.11/dist-packages/IPython/core/interactiveshell.py:3553: LangChainDeprecationWarning: As of langchain-core 0.3.0, LangChain uses pydantic v2 internally. The langchain_core.pydantic_v1 module was a compatibility shim for pydantic v1, and should no longer be used. Please update the code to import from Pydantic directly.
#
# For example, replace imports like: `from langchain_core.pydantic_v1 import BaseModel`
# with: `from pydantic import BaseModel`
# or the v1 compatibility namespace if you are working in a code base that has not been fully upgraded to pydantic 2 yet. 	from pydantic.v1 import BaseModel
#
#   exec(code_obj, self.user_global_ns, self.user_ns)
# Mounted at /content/drive

# %%
#@title Функии

# Функция для форматирования текста по абзацам
def format_text(text, width=120):
    # Разделяем текст на абзацы
    paragraphs = str(text).split('\n')
    # Форматируем каждый абзац отдельно
    formatted_paragraphs = []
    for paragraph in paragraphs:
        # Используем textwrap.fill для форматирования абзаца, чтобы длина строки не превышала width
        formatted_paragraph = textwrap.fill(paragraph, width)
        formatted_paragraphs.append(formatted_paragraph)
    # Объединяем абзацы с символом новой строки
    return '\n'.join(formatted_paragraphs)


# Функция записи логов в файл _log.txt
def add_log_file(text, title=''):
    time_now = f"{datetime.now().strftime('%Y-%m-%d %H:%M')}"
    with open(os.path.join(path, '_log.txt'), "a", encoding='utf-8') as file:
            file.write(f'\n\n{time_now}. {title}.\n\n{format_text(text)}')


# Функция подсчета количества используемых токенов и стоимость
# https://openai.com/pricing
def print_tokens_count_and_price(completion, model):
    if model == "gpt-4o":
        # gpt-4o - Input: $5 / 1M tokens - Output: $15 / 1M tokens
        input_price, output_price = 5, 15
    if model == "gpt-4o-mini":
        # gpt-4o-mini - Input: $0.15 / 1M tokens - Output: $0.60 / 1M tokens
        input_price, output_price = 0.15, 0.60
    price = input_price * completion.usage.prompt_tokens / 1e6 + \
            output_price * completion.usage.completion_tokens / 1e6
    print(f'Tokens used: {completion.usage.prompt_tokens} + '
                       f'{completion.usage.completion_tokens} = '
                       f'{completion.usage.total_tokens}. '
                       f'*** {model} *** $ {round(price, 5)}')


# Функция генерации ответа от OpenAI
def generate_answer(prompt_system, prompt_user, prompt_assistant='', model='gpt-4o-mini', temp=0.1):
    messages = [
        {"role": "system", "content": prompt_system},
        {'role': 'assistant', 'content': prompt_assistant},
        {"role": "user", "content": prompt_user}
    ]
    response = openai.chat.completions.create(
        model=model,
        messages=messages,
        temperature=temp,
        # max_tokens=4000
    )
    # Вывод количества используемых токенов и стоимость
    print_tokens_count_and_price(response, model=model)
    # Запись в лог-файл
    add_log_file(f'\n{messages}\n{response.choices[0].message.content}\n\n\n', title='generate_answer()')
    return response.choices[0].message.content


# Чтение PDF файла
def read_pdf(pdf_file):
    reader = PdfReader(pdf_file)
    # возвращаем текст построчно
    return ' '.join([line.extract_text() for line in reader.pages])


# Формируем поля для парсига Вакансии для последующего использовании при поиске
# https://python.langchain.com/v0.1/docs/modules/model_io/output_parsers/types/json/
"""Класс Vacancy с использованием библиотеки Pydantic, который будет использоваться для парсинга
   вакансий. Класс имеет четыре поля: position, skills, requirements и responsibilities. Описание
   для каждого поля включает инструкцию по извлечению соответствующих данных из текста вакансии."""

add_prompt = "Иначе, выведи ответ: None"
class Vacancy(BaseModel):
    position: str = Field(
        description = f'Найди в тексте вакансии название должности (позиции). {add_prompt}')
    skills: str = Field(
        description = re.sub(r'\s+', ' ', f"""Найди в тексте вакансии все указанные навыки.
                      {add_prompt}"""))
    requirements: str = Field(
        description = re.sub(r'\s+', ' ', f"""Найди в тексте вакансии все указанные требования.
                      {add_prompt}"""))
    responsibilities: str = Field(
        description = re.sub(r'\s+', ' ', f"""Найди в тексте вакансии все указанные обязанности.
                      {add_prompt}"""))


# Формируем поля для парсига Резюме для последующего использовании при поиске
# https://python.langchain.com/v0.1/docs/modules/model_io/output_parsers/types/json/
"""Класс Resume с использованием библиотеки Pydantic, который будет использоваться для парсинга
   резюме. Класс имеет три поля: position, skills и experience. Описание для каждого поля включает
   инструкцию по извлечению соответствующих данных из текста вакансии."""

add_prompt = "Иначе, выведи ответ: None"
class Resume(BaseModel):
    position: str = Field(
        description = f'Найди в тексте резюме название должности (позиции). {add_prompt}')
    skills: str = Field(
        description = re.sub(r'\s+', ' ', f"""Найди в тексте резюме все указанные навыки (стек).
                      {add_prompt}"""))
    experience: str = Field(
        description = re.sub(r'\s+', ' ', f"""Найди в тексте резюме описание прошлого опыта с
                      описанием деятельности. {add_prompt}"""))


# Парсинг текста с формированием полей по параметрам (parser_class=Vacancy или Resume)
# JSON parser https://python.langchain.com/v0.1/docs/modules/model_io/output_parsers/types/json/
def to_dict_parser(text, parser_class, model='gpt-4o') -> dict:
    # text: текст для парсинга
    # parser_class: класс парсера (например, Vacancy или Resume)
    # model: имя модели для генерации текста (по умолчанию 'gpt-4o')

    # Экземпляр JsonOutputParser (из langchain)
    parser = JsonOutputParser(pydantic_object=parser_class)
    prompt = PromptTemplate(
        input_variables = ["query"],
        # шаблон с инструкциями
        template = "Follow the instructions:\n"
                   "{format_instructions}\n"
                   "{query}\n",
        # встроенные инструкции JsonOutputParser по форматированию
        partial_variables = {"format_instructions": parser.get_format_instructions()})

    # цепочка (chain) из шаблона, модели и парсера
    # оператор '|' означает последовательное выполнение: шаблон -> модель -> парсер
    model = ChatOpenAI(model=model, temperature=0)
    chain = prompt | model | parser
    return chain.invoke({"query": text})


# Парсинг PDF файлов Вакансий и подготовка чанков для векторизации
# Cохранение данных вакансий в Json для удобства последующего использования
def pdf_to_json_and_chunks_vacancies(path_vacancies_pdf, model='gpt-4o-mini'):
    chunks_vacancies = [] # список для хранения чанков
    for file in os.listdir(path_vacancies_pdf): # Перебираем все файлы в указанной директории
        if file.endswith('.pdf'): # является ли файл PDF
            # From PDF to text
            vacancy = read_pdf(os.path.join(path_vacancies_pdf, file))
            add_log_file(vacancy, title='vacancy')
            # Парсинг текста вакансии и преобразование его в словарь с использованием заданного парсера и модели
            dict_vacancy = to_dict_parser(vacancy, parser_class=Vacancy, model=model)
            add_log_file(dict_vacancy, title='vacancy_to_dict_parser')

            vacancy_id = file.split('.')[0] # Имя файла без расширения .pdf
            # записываем в словарь дополнительные поля
            dict_vacancy['id'] = vacancy_id
            dict_vacancy['vacancy'] = vacancy # в т.ч. Вакансию целиком в словарь

            # Сохрание всех данных словаря в Json файл
            with open(os.path.join(path_vacancies_json, f'{vacancy_id}.json'), 'w', encoding='utf-8') as f:
                json.dump(dict_vacancy, f, ensure_ascii=False)

            # Формирование чанка для векторной базы вакансий
            chunk = re.sub(r'\s+', ' ',
                        f"""1.Позиция: {dict_vacancy.get('position', '')}.
                            2.Навыки: {dict_vacancy.get('skills', '')}.
                            3.Требования: {dict_vacancy.get('requirements', '')}.
                            4.Обязанности: {dict_vacancy.get('responsibilities', '')}.""")
            # Добавляем чанк каждой вакансии в список в формате Langchain Document
            chunks_vacancies.append(Document(page_content=chunk,
                                    metadata={"meta": f"{vacancy_id}"}))
    add_log_file(chunks_vacancies, title='pdf_to_json_and_chunks_vacancies')
    return chunks_vacancies # список чанков вакансий


# Парсинг PDF файлов Резюме и подготовка чанков для векторизации
# Cохранение данных резюме в Json для удобства последующего использования
def pdf_to_json_and_chunks_resumes(path_resumes_pdf, model='gpt-4o'):
    chunks_resumes = [] # список для хранения чанков
    for file in os.listdir(path_resumes_pdf): # Перебираем все файлы в указанной директории
        if file.endswith('.pdf'): # является ли файл PDF
            # From PDF to text
            resume = read_pdf(os.path.join(path_resumes_pdf, file))
            add_log_file(resume, title='read_pdf_resume')
            # Парсинг текста резюме и преобразование его в словарь с использованием заданного парсера и модели
            dict_resume = to_dict_parser(resume, parser_class=Resume, model=model)
            add_log_file(dict_resume, title='resume_to_dict_parser')

            resume_id = file.split('.')[0] # Имя файла резюме без расширения .pdf
            # записываем в словарь дополнительные поля
            dict_resume['id'] = resume_id
            dict_resume['resume'] = resume # в т.ч. Резюме целиком в словарь

            # Сохрание всех данных словаря в Json файл
            with open(os.path.join(path_resumes_json, f'{resume_id}.json'), 'w', encoding='utf-8') as f:
                json.dump(dict_resume, f, ensure_ascii=False)

            # Формирование чанка для векторной базы резюме
            chunk = re.sub(r'\s+', ' ',
                        f"""1.Позиция: {dict_resume.get('position', '')}.
                            2.Навыки: {dict_resume.get('skills', '')}.
                            3.Опыт: {dict_resume.get('experience', '')}.""")
            # Добавляем чанк каждого резюме в список в формате Langchain Document
            chunks_resumes.append(Document(page_content=chunk,
                                  metadata={"meta": f"{resume_id}"}))
    add_log_file(chunks_resumes, title='pdf_to_json_and_chunks_resumes')
    return chunks_resumes # список чанков


# Поиск релевантных чанков по запросу
def scores_and_meta_similarity(query, db_index, k=3):
    # query: текст для поиска релевантой информации
    # db_index: векторная база данных
    # k: количество возвращаемых результатов (по умолчанию 3)

    # Нахождение наиболее похожих документов на основе заданного запроса
    docs_and_scores = db_index.similarity_search_with_score(query, k=k)
    add_log_file(docs_and_scores, title='scores_and_meta_similarity')
    return ([doc[1] for doc in docs_and_scores],                   # List оценок (score) по результатам поиска
            [doc[0].metadata['meta'] for doc in docs_and_scores])  # Мeta list с именами файлов


# Загрузка фала из GoogleDisk по открытой ссылке
def download_from_google_disk(link, output_path):
    # link: открытая ссылка на файл в Google Диске
    # output_path: путь, куда будет сохранен загруженный файл
    # Идентификатор файла - это последовательность из 25 или более символов (букв, цифр, подчеркиваний, дефисов)
    id = re.findall(r'/d/([a-zA-Z0-9_-]{25,})', link)  # Находим идентификатор файла в ссылке
    direct_link = f'https://drive.google.com/uc?export=download&id={id[0]}'  # Формируем прямую ссылку
    add_log_file(direct_link, title='google_link') # Запись в лог-файл
    gdown.download(direct_link, output_path, quiet=True) # загрузка


# Загрузка фала из YandexDisk
def download_from_yandex_disk(link, output_path):
    # link: ссылка на файл в Yandex Диске
    # output_path: путь, куда будет сохранен загруженный файл
    # Базовый URL для получения информации о ресурсе
    base_url = 'https://cloud-api.yandex.net/v1/disk/public/resources?'
    # Формируем финальный URL для запроса информации о ресурсе
    final_url = base_url + urlencode(dict(public_key=link))
    # Делаем запрос для получения информации о ресурсе
    response = requests.get(final_url)
    resource_info = response.json()
    # Получаем ссылку на скачивание файла
    download_url = resource_info['file']
    # Получаем имя файла
    file_name = resource_info['name']
    # Скачиваем файл
    download_response = requests.get(download_url)
    with open(os.path.join(output_path, file_name), 'wb') as f:
        f.write(download_response.content)
    add_log_file(link, title='yandex_link') # Запись в лог-файл


# Разархивирование содержимого архива в ту же папку
def unrar(path):
    for rar in os.listdir(path): # пробегаем по всем файлам в папке
        if rar.endswith('.rar'): # является ли файл арховом RAR
            filepath = os.path.join(path, rar) # путь к RAR файлу
            with rarfile.RarFile(filepath) as opened_rar:
                opened_rar.extractall(path) # разархивирование в ту же папку


# Функция дублирования строки с символом '#...'
def duplicate_lines(text):
    lines = text.split('\n')
    result = []
    for line in lines:
        if line.startswith('#'): # строка с символом '#...'
            result.append(line)
        result.append(line.lstrip('# ')) # дублируем без '#'
    return '\n'.join(result)


# Создание векторной базы из текстового файла с Markdown разметкой
def db_from_markdown_file(markdown_file):
    # Открываем и читаем содержимое Markdown файла
    with open(markdown_file, 'r', encoding='utf-8') as f:
        markdown_info = f.read()
    markdown_info = duplicate_lines(markdown_info)
    # Определяем заголовки, по которым будет выполняться разбиение текста
    # В данном случае, это заголовки уровня 1 (#)
    headers_to_split_on = [("#", "Header 1"),]
    # Экземпляр MarkdownHeaderTextSplitter с указанными заголовками для разбиения текста
    splitter = MarkdownHeaderTextSplitter(headers_to_split_on=headers_to_split_on)
    # Разбиваем содержимое Markdown файла на чанки на основе заголовков
    chunks = splitter.split_text(markdown_info)
    # Создаем и возвращаем векторную базу данных FAISS
    return FAISS.from_documents(chunks, OpenAIEmbeddings())


# Функция диалога, поочередной подачи вопросов из списка и получение ответов
def ask_questions(questions):
    responses = []
    for question in questions:

        print(format_text(f"Рекрутер: {question}"), '\n')
        answer = input("Кандидат: ")
        formatted_answer = format_text(f"Кандидат: {answer}")
        # добаляем историю диалога в список
        responses.append(f"{question}\n\n{formatted_answer}\n\n")
        print('\n')
    add_log_file(responses, title='ask_questions(questions)')
    return responses


# Функция типовых вопросов
def conduct_interview(resume):
    text_start = f'Рекрутер: Здравствуйте! Давайте начнем собеседование. План собеседования следующий: \n 1. Я задам Вам несколько вопросов. \n 2. Расскажу о нашей компании и имеющейся вакансии \n 3. Отвечу на Ваши вопросы. \n Общайтесь пожалуйста со мной как с обычным рекрутером!'
    print(text_start, '\n')
    interview_summary = [f"Резюме:\n{resume}\n", "Интервью:\n"]
    # добаляем историю диалога в список
    interview_summary.extend(ask_questions(questions))
    add_log_file("\n".join(interview_summary), title='conduct_interview')
    # возвращаем резюме и историю диалога в текстовом виде (str)
    return "\n".join(interview_summary)


# Функция анализа диалога и генерация доп. вопросов
def generate_dialogue(prompt_system, prompt_user, model='gpt-4o'):
    print(f'Рекрутер: Подождите минутку. Я проанализирую Ваши ответы и сформулирую дополнительные вопросы.', '\n')
    answer = generate_answer(prompt_system, prompt_user, model=model)
    print(format_text(answer))
    return answer


# Функция дополнительных вопросов
def ask_additional_questions(questions):
    question_list = questions.split('\n') # формируем список из строк
    question_list = [q for q in question_list if q.strip()] # убираем из списка пустые строки
    additional_responses = ask_questions(question_list) # функция диалога
    add_log_file(additional_responses, title='ask_additional_questions') # Запись в лог-файл
    return additional_responses


# Функция презентации компании
def present_company_and_vacancy(company_description):
    text_presentation = f'Рекрутер: Спасибо, что ответили на все дополнительные вопросы. Теперь я хочу подробнее рассказать Вам о нашей организации. Нажмите Enter, когда будете готовы.'
    print(format_text(text_presentation), '\n')
    input()
    print(format_text(company_description), '\n\n')


# Функция ответа на вопросы кандидата
def handle_candidate_questions(candidate_position,
                               prompt_candidate_questions,
                               query_candidate_questions_template,
                               db_company_info,
                               model='gpt-4o-mini'):
    text_candidate_questions = f'Рекрутер: Если у Вас остались какие-либо вопросы, задайте их, пожалуйста, и я постараюсь ответить. Если вопросов нет, просто напишите "вопросов нет", и мы завершим наше собеседование.'
    print(format_text(text_candidate_questions), '\n\n')

    while True:
        candidate_question = input("Кандидат: ")
        print()
        if candidate_question.strip().lower() == 'вопросов нет':
            print("Рекрутер: Спасибо за собеседование! Желаем Вам удачи!")
            break
        candidate_question = f'Вопрос к позиции: {candidate_position}: {candidate_question}'
        # Полный вопрос кандидата с промптом
        query_candidate_questions = query_candidate_questions_template.format(candidate_question=candidate_question)
        # нахождение наиболее похожих документов на основе заданного вопроса кандидата
        docs = db_company_info.similarity_search(candidate_question, k=3) # search similarity

        # из списока объектов базы знаний docs, извлекаем атрибуты page_content (содержание документов) из каждого docs,
        # добавляем заголовок с форматом '\nChank {i+1}:\n' и объединяем их в строку с одним пробелом между каждым элементом.
        message_content = re.sub(r'\n{2}', ' ', '\n '.join([f'\nChank {i+1}:\n' + \
                                                      doc.page_content + '\n' for i, doc in enumerate(docs)]))

        query_candidate_questions = f'# База знаний для ответов: \n{message_content} \n# {query_candidate_questions}'
        # Функция генерации ответа на вопрос
        answer = generate_answer(prompt_candidate_questions, query_candidate_questions, model=model, temp=0.3)
        add_log_file(f'{query_candidate_questions}\n{answer}', title='handle_candidate_questions')
        print("Рекрутер: " + format_text(answer))
        print()


# Функция генерации оценки кандидата
def generate_estimation(prompt_system, prompt_user, model='gpt-4o-mini'):
    print("Итоговый отчет по кандидату:", '\n')
    answer = generate_answer(prompt_system, prompt_user, model=model)
    print(format_text(answer))
    return answer

# %%
#@title Загрузка PDF файлов вакансий и резюме

# Загрузка PDF файлов вакансий в RAR архиве
rar_vacancies = 'https://disk.yandex.ru/d/ece3qxT53I5CMw'
download_from_yandex_disk(rar_vacancies, path_vacancies_pdf)
unrar(path_vacancies_pdf) # разархивирование PDF вакансий в ту же папку

# Загрузка PDF файлов резюме в RAR архиве
rar_resumes = 'https://disk.yandex.ru/d/vxGW7qNelVT0YA'
download_from_yandex_disk(rar_resumes, path_resumes_pdf)
unrar(path_resumes_pdf) # разархивирование PDF резюме в ту же папку

# %%
#@title Парсинг PDF, создания векторных баз

# Cоздание или очистка файла логов
open(os.path.join(path, '_log.txt'), 'w').close()

# Парсинг PDF файлов вакансий и резюме. Формирование чанков. Сохранение в Json
chunks_vacancies = pdf_to_json_and_chunks_vacancies(path_vacancies_pdf)
chunks_resumes = pdf_to_json_and_chunks_resumes(path_resumes_pdf)

# Создание и сохранение векторной базы вакансий для последующего релевантного поиска
db_vacancies = FAISS.from_documents(chunks_vacancies, OpenAIEmbeddings())
db_vacancies.save_local(folder_path=path_db_faiss, index_name='db_vacancies')

# Создание и сохранение векторной базы резюме для последующего релевантного поиска
db_resumes = FAISS.from_documents(chunks_resumes, OpenAIEmbeddings())
db_resumes.save_local(folder_path=path_db_faiss, index_name='db_resumes')

# %%
#@title Создаем векторную базу ответов от HR

# Загружаем текстовый файл c информацией от HR с разметкой Markdown
hr_answers_link = 'https://disk.yandex.ru/d/u87B3pc1PrWwuQ'
download_from_yandex_disk(hr_answers_link, path_add_data)

# Создаем векторную базу с ответами от HR по каждой позиции и сохраняем
db_hr_answers = db_from_markdown_file(os.path.join(path_add_data, 'hr_answers.txt'))
db_hr_answers.save_local(folder_path=path_db_faiss, index_name='db_hr_answers')

# В векторной базе ответов от HR позиции на написаны русском, поэтому позже будем использовать словарь
positions = {'Python_Dev': 'Разработчик',
             'Head_of_sales': 'Руководитель отдела продаж',
             'HR_Director': 'Директор по пресоналу'}

# %% [markdown]
# # Режим соискателя.
# # Поиск подходящей вакансии из базы на основе предоставленного резюме.
# # Анализ. Собеседование с кандидатом (Python Developer).

# %%
#@title Поиск релевантных вакансий под конкретное резюме

# Для примера, берем резюме 'Resume Backend Dev+.pdf'
resume = read_pdf(os.path.join(path_resumes_pdf, 'Resume Python_Dev+.pdf'))

# Загружаем векторную базу вакансий.
db_vacancies = FAISS.load_local(folder_path=path_db_faiss,
                                allow_dangerous_deserialization=True,
                                embeddings=OpenAIEmbeddings(),
                                index_name='db_vacancies')

# Поиск релевантных вакансий под указанное резюме.
similarity_info = scores_and_meta_similarity(resume, db_vacancies, k=3)
print(similarity_info)
print(f"\nНаиболее подходящая вакансия определена: {similarity_info[1][0]} с наименьшим значенинем score")

# Пробегаем по словарю для выбора русскоязычной позиции для ответов HR
for k, v in positions.items():
    if k in similarity_info[1][0]:
        candidate_position = v
print(f'Будут спользованы ответы от HR для позиции: {candidate_position}')

# Загружаем наиболее релевантную вакансию по наименьшему значению score из поля Json файла
with open(os.path.join(path_vacancies_json, f'{similarity_info[1][0]}.json'), 'r', encoding='utf-8') as f:
    vacancy_json_info = json.load(f)
    vacancy = vacancy_json_info['vacancy']
# Out:
# ([np.float32(0.22211277), np.float32(0.3657394), np.float32(0.38696077)], ['Python_Dev', 'HR_Director', 'Head_of_sales'])
#
# Наиболее подходящая вакансия определена: Python_Dev с наименьшим значенинем score
# Будут спользованы ответы от HR для позиции: Разработчик

# %%
#@title Типовые вопросы

# Загружаем файл general_questions.json
# В котором типовые вопросы для всех позиций ('Python_Dev', 'Head_of_sales', 'HR_Director')
general_questions_link = 'https://disk.yandex.ru/d/fT1nVglFz-g_Dg'
download_from_yandex_disk(general_questions_link, path_add_data)
with open(os.path.join(path_add_data, 'general_questions.json'), 'r', encoding='utf-8') as f:
    general_questions = json.load(f)

# Пробегаем по названиям полей Json
for key in general_questions:
    # Ищем соответсвие поля json 'Python_Dev' и названия позиции 'Python_Dev'
    if key in f'{similarity_info[1][0]}':
        # берем список вопросов на соответствующую позицию. В данном случае 'Python_Dev'
        questions = general_questions[key]

# %%
#@title **Начинаем собеседование**

# Cоздание или очистка файла логов
open(os.path.join(path, '_log.txt'), 'w').close()

# Вызываем функцию старта собеседования
interview_summary = conduct_interview(resume)
# Out:
# Рекрутер: Здравствуйте! Давайте начнем собеседование. План собеседования следующий:
#  1. Я задам Вам несколько вопросов.
#  2. Расскажу о нашей компании и имеющейся вакансии
#  3. Отвечу на Ваши вопросы.
#  Общайтесь пожалуйста со мной как с обычным рекрутером!
#
# Рекрутер: Какой у Вас общий опыт работы с Python?
#
# Кандидат: 2 года опыта коммерческой разработки. Также есть несколько pet-проектов и дипломных работ, так как на Python пишу ещё со школьных времен.
#
#
# Рекрутер: С какими фреймворками работали?
#
# Кандидат: Из фреймворков работала с Flask, PyQt, PyTorch. Также есть опыт с библиотеками: numpy, pandas, scipy - для обработки 3D данных, SQLAlchemy - ORM для работы с БД (у нас была PostgreSQL). Имею базовые навыки frontend разработки (HTML, CSS, JavaScript). Есть опыт работы с брокерами сообщений (например, RabbitMQ)
#
#
# Рекрутер: Расскажите про Ваши самые значимые достижения в работе (2-3 примера)
#
# Кандидат: Одним из моих самых значимых достижений является то, что после ухода тимлида из нашей команды пул его административных задач перешел мне, так как руководитель отметил мои лидерские качества, повышенный уровень ответственности и систематичность. Таким образом, помимо задач по разработке, я взяла на себя обязанности по управлению проектами. Поскольку я уже являлась лидером команды, я стала инициировать улучшение процессов, а именно внедрила скрам, т.е. разработку спринтами. Также мне удалось внедрить и наладить код-ревью, но конечно не без помощи команды, вместе с коллегами мы разработали внутренние регламенты для рецензирования кода. Если говорить о моих достижениях в области разработки, то я бы выделила свой навык устранять легаси. Я занималась поддержкой существующих веб-сервисов и разрабатывала свои, и в какой-то момент из стало слишком много. Я поняла, что у них есть общие части и реорганизовала старый код, выделила базовые сущности. Это облегчило процесс разработки, так как больше не нужно было, например, добавлять новый функционал во все сервисы, можно было единожды расширить функционал базового класса. Также моей зоной ответственности был ""центровой"" сервис, который координировал работу всего приложения. Мне нужно было собрать воедино все элементы и заставить это работать. Коллеги отмечали мою способность быстро локализовать ошибки,. Этого мне удалось достичь благодаря качественному логированию и бэкапу данных, которые я настроила в своем сервисе.
#
#
# Рекрутер: Опишите почему выбрали предыдущее место работы. Чем руководствовались при выборе?
#
# Кандидат: Меня привлекла новая интересная область (роботизация, металлообработка), а также то, что компания создает уникальный продукт. Помимо этого работа с роботами подразумевает наличие развитого пространственного мышления и хорошую математическую подготовку, мне очень нравилось применять эти свои навыки в работе
#
#
# Рекрутер: Почему ушли (или уходите) с последнего места работы?
#
# Кандидат: Я поняла, что достигла некоторого предела, и моё развитие как разработчика замедлилось. Я связываю это с тем, что в команде мы все имели примерно одинаковый уровень. Также у меня было ощущение, что руководитель не поддерживает мои инициативы по развитию процессов, и я приняла решение покинуть это место
#
#
# Рекрутер: Что, по-вашему мнению, является главной мотивацией в работе Python - разработчика?
#
# Кандидат: Главной мотивацией является цель, которая заключается в создании продукта или услуги, а также понимание того, как этот товар или услуга изменит мир. То есть главным является смысл и миссия продукта
#
#
# Рекрутер: С какими проблемами сталкивались на предыдущих местах работы?
#
# Кандидат: Я столкнулась с проблемой, когда получила повышение и стала руководителем проектов. Мне было сложно перестроить отношения с коллегами, так как еще вчера мы были с ними наравне, а сегодня я требую от них выполнения задач. Мне удалось это пережить, так как со временем коллеги поняли, к какому результату я их веду. Я объясняла им свои решения, и это помогло мне получить их доверие. Также сложно было показать руководителю, почему необходимо наладить процессы разработки, так как он сам не являлся разработчиком. Однако он понял, что стоит дать шанс, когда мы с командой объяснили важность этого улучшения
#
#
# Рекрутер: Что для вас неприемлемо в работе?
#
# Кандидат: Насилие в любом его проявлении: физическое и психологическое.  Непрофессиональное поведение, когда собственные (корыстные) интересы ставятся выше интересов компании или команды.  Игнор. Для эффективной работы мне необходим налаженный контакт и коммуникация со всеми членами команды
#
#
# Рекрутер: Расставьте в порядке приоритетности при выборе работы: Доход; Удобный график работы; Идея компании (то, что
# компания несёт в мир); Стабильность компании; Статусность компании; Команда, коллектив; Качественный продукт; Хорошее
# отношение руководителя; Профессиональный рост
#
# Кандидат: Идея компании (то, что компания несёт в мир), Команда, коллектив, Хорошее отношение руководителя, Профессиональный рост, Доход, Стабильность компании, Качественный продукт, Статусность компании, Удобный график работы
#
#
# Рекрутер: Сколько часов в неделю готовы работать?
#
# Кандидат: 40
#
#
# Рекрутер: Ради чего готовы работать 60 часов в неделю?
#
# Кандидат: Ради выполнения общей цели, ради того, чтобы мы с командой достигли видимого результата (например, когда приближается дедлайн). Также я могу это делать в тех случаях, когда я вижу (или мне предлагают) возможности для горизонтального или вертикального развития, т.е. для того чтобы изучить новую область и получить навыки в новой сфере. У меня был похожий опыт, когда я совмещала работу на полный день и обучение в магистратуре
#
#
# Рекрутер: Какой вариант выберете: небольшой фикс в зарплате и большой kpi от результата; или выше фикс в зарплате и
# меленький kpi? (Суммарно в первом варианте заработать можно больше)
#
# Кандидат: Если в первом варианте можно заработать больше, то я бы выбрала его, так как я умею планировать свое время и выполнять задачи в срок. Также мне нравится эта идея тем, что я могу непосредственно влиять на уровень своего дохода. Однако у меня всё равно есть сомнения, я никогда не работала по такой системе. В любом случае всё зависит от того, как рассчитывается KPI. Если для меня это будет оставаться непонятной и непрозрачной мерой оценки, то я буду вынуждена выбрать второй вариант, где более высокий фикс
#
#
# Рекрутер: На какой уровень дохода рассчитываете?
#
# Кандидат: 150 000 рублей
#
#
# Рекрутер: Как вы считаете, как часто надо коммуницировать с командой, руководителем и какие вопросы стоит раскрывать на
# встречах?
#
# Кандидат: С командой - каждый день, с руководителем - 2-3 раза в неделю
#
#
# Рекрутер: Расставьте в порядке приоритетности: семья, комфортная жизнь, доход, карьера.
#
# Кандидат: Комфортная жизнь, карьера, доход, семья
#
#
# Рекрутер: В каком виде для вас идеально получить задачу, чтобы работа шла гладко?
#
# Кандидат: В идеале постановка задачи должна удовлетворять принципам SMART: задача должна быть четко сформулирована, должно быть понятно, что является результатом выполнения задачи, у задачи должен быть приоритет и срок исполнения
#
#
# Рекрутер: Есть ли у вас дети? Если да, то напишите их возраст?
#
# Кандидат: Нет
#
#
# Рекрутер: Какое минимальное описание задачи вам достаточно, чтобы выполнить работу хорошо для проекта и в нужные сроки?
#
# Кандидат: Я думаю, что достаточно описания на уровне "Вход, Выход, Краткое описание проблемы". То есть понятны входные данные, проблема (что должно быть исправлено или реализовано) и выходные данные (результат). Также не должно возникать конфликта между задачами, т.е. нужно понимание насколько это важно и срочно
#
#
# Рекрутер: Вам необходимо было собрать данные для аналитики, а вы сделали работу совсем не так, и руководитель даёт
# критику на вашу выполненную работу. Какие ваши действия/реакция?
#
# Кандидат: Я выслушаю руководителя и постараюсь выяснить, что конкретно я сделала не так и чего ожидал руководитель. Мне необходимо понять, где произошло недопонимание, чтобы в будущем избежать подобных ошибок
#
#
# Рекрутер: Руководитель поручил Вам ответственную задачу, но при этом вы понимаете, что не успеваете уложиться в рабочее
# время и нужно будет поработать в выходной день, чтобы выполнить поставленную задачу. При этом вы уже пообещали семье,
# что в пятницу вечером сразу после работы поедете на дачу, так как эта поездка была давно запланирована. Как поступите в
# данной ситуации?
#
# Кандидат: Зависит от того, насколько ответственная задача и как часто я провожу время с семьей. Если я понимаю, что эту задачу кроме меня может выполнить кто-то другой, или что задача может подождать понедельника, то я предложу руководителю варианты передать завершение задачи коллеге или предоставить еще немного времени. Однако это может не подойти, тогда я отложу поездку с семьей до следующей недели
#
#
# Рекрутер: Когда готовы приступить к работе?
#
# Кандидат: В ближайшее время
#
#
# Рекрутер: Укажите следующие данные, по которым мы могли бы запросить рекомендацию по вам (можно несколько): Название
# компании. ФИО и должность того, кто смог бы вас порекомендовать. Контактный номер телефона этого человека.
#
# Кандидат: Компания АБВ. Иванов Иван Иванович. +7 915 0000000

# %%
#@title Генерируем дополнительные вопросы

prompt_additional_questions = f"""
Ты рекрутер, проводящий собеседование с кандидатом.
Твоя задача — задать 10 (десять) коротких и четких вопросов кандидату, чтобы выявить его навыки и опыт.
Ты очень критичный в отборе кандидатов и очень скептически относишься ко всем из словам, где кандидат хвалит себя.
"""
query_additional_questions = f"""
# Вот информация о кандидате (резюме, вопросы и ответы): \n{interview_summary}\n
# Ты подбираешь кандидата на вакансию: \n{vacancy}\n
# Задай вопросы на основании резюме кандидата, на основании ранее заданных вопросов
  кандидату и полученных от него ответов, а также вакансии.
# Нужно выявить дополнительную информацию, если этой информации ещё НЕ было в предыдущих ответах кандидата:
## Каких навыков и опыта НЕ хватает кандидату по сравнению с требуемыми навыками из вакансии.
   Навыки и опыт кандидата из резюме и из предыдущих ответов кандидата сравни с требованиями,
   предъявляемыми в вакансии и задай вопросы кандидату касательно навыков и опыта, которых кандидату НЕ достаточно.
## Мотивация, командная работа и коммуникационные навыки
# Задавай вопросы с новой строчки.
# Задай два неудобных или неожиданных вопроса, которые помогут выявить слабые стороны кандидата.
# Задай пару вопросов, направленных на выявление несоответствий в ответах кандидата с данными резюме кандидата.
# Не пиши тему вопроса и не разбивай их на группы, просто подай списком в случайном порядке.
# Задай 10 (десять) вопросов кандидату.
"""
# Генерация доп. вопросов
additional_questions = generate_dialogue(prompt_additional_questions,
                                         query_additional_questions, model="gpt-4o")
# Out:
# Рекрутер: Подождите минутку. Я проанализирую Ваши ответы и сформулирую дополнительные вопросы.
#
# Tokens used: 4441 + 375 = 4816. *** gpt-4o *** $ 0.02783
# 1. Вы упомянули опыт работы с Flask, но в вакансии также требуется знание Django. Есть ли у вас опыт работы с Django, и
# если нет, как быстро вы готовы его освоить?
#
# 2. В вашем резюме не упоминается опыт работы с GIT. Как вы управляете версиями кода и работали ли вы с системами
# контроля версий?
#
# 3. Вы говорили о работе с PostgreSQL, но в вакансии также упоминается MySQL. Есть ли у вас опыт работы с MySQL?
#
# 4. В вакансии упоминается использование Docker-контейнеров. Есть ли у вас опыт работы с Docker, и если нет, как вы
# планируете его освоить?
#
# 5. Вы упомянули, что готовы работать 40 часов в неделю, но также говорили о возможности работать 60 часов ради
# достижения цели. Как вы планируете балансировать между работой и личной жизнью в таких ситуациях?
#
# 6. Вы сказали, что готовы работать ради выполнения общей цели. Как вы определяете, что цель действительно стоит ваших
# усилий?
#
# 7. Вы упомянули, что достигли предела на предыдущем месте работы. Как вы планируете избежать подобной ситуации в нашей
# компании?
#
# 8. В вашем резюме указано, что вы занимались внедрением скрам и код-ревью. Как вы оцениваете успех этих инициатив и что
# бы вы сделали по-другому?
#
# 9. Вы говорили о важности идеи компании и команды. Как вы реагируете, если ваши ожидания от компании или команды не
# оправдываются?
#
# 10. Вы упомянули, что можете отложить поездку с семьей ради работы. Как часто вы готовы жертвовать личными планами ради
# профессиональных обязанностей?

# %%
#@title Задаем дополнительные вопросы
interview_summary += "\n".join(ask_additional_questions(additional_questions))
# Out:
# Рекрутер: 1. Вы упомянули опыт работы с Flask, но в вакансии также требуется знание Django. Есть ли у вас опыт работы с
# Django, и если нет, как быстро вы готовы его освоить?
#
# Кандидат: У меня нет практического опыта работы с Django, однако я знакома с его основами и принципами, так как изучала его в рамках самообразования. Поскольку я уже имею опыт работы с Flask и другими фреймворками, я уверена, что смогу освоить Django в течение 2-3 недель, активно изучая документацию и применяя знания на практике
#
#
# Рекрутер: 2. В вашем резюме не упоминается опыт работы с GIT. Как вы управляете версиями кода и работали ли вы с
# системами контроля версий?
#
# Кандидат: Да, конечно, GIT известен, использовался в работе
#
#
# Рекрутер: 3. Вы говорили о работе с PostgreSQL, но в вакансии также упоминается MySQL. Есть ли у вас опыт работы с
# MySQL?
#
# Кандидат: У меня есть опыт работы с PostgreSQL. Я уверена, что смогу быстро освоить MySQL, так как структуры данных и SQL-запросы в MySQL схожи с PostgreSQL.
#
#
# Рекрутер: 4. В вакансии упоминается использование Docker-контейнеров. Есть ли у вас опыт работы с Docker, и если нет,
# как вы планируете его освоить?
#
# Кандидат: У меня нет практического опыта работы с Docker, однако я изучала его основы. Я понимаю концепции контейнеризации и оркестрации, и, учитывая мою способность к быстрому обучению, я полагаю, что смогу освоить Docker за 2 недели, активно изучая документацию и пробуя развертывать контейнеры для различных сервисов
#
#
# Рекрутер: 5. Вы упомянули, что готовы работать 40 часов в неделю, но также говорили о возможности работать 60 часов ради
# достижения цели. Как вы планируете балансировать между работой и личной жизнью в таких ситуациях?
#
# Кандидат: Я готова работать сверхурочно по необходимости, чтобы достичь общих целей проекта.
#
#
# Рекрутер: 6. Вы сказали, что готовы работать ради выполнения общей цели. Как вы определяете, что цель действительно
# стоит ваших усилий?
#
# Кандидат: Это цель, достижение которой приносит пользу людям и справедливо вознаграждается вложенный труд
#
#
# Рекрутер: 7. Вы упомянули, что достигли предела на предыдущем месте работы. Как вы планируете избежать подобной ситуации
# в нашей компании?
#
# Кандидат: Я хочу углубить знания в области AI и машинного обучения, а также развивать навыки в области разработки алгоритмов и анализа данных.
#
#
# Рекрутер: 8. В вашем резюме указано, что вы занимались внедрением скрам и код-ревью. Как вы оцениваете успех этих
# инициатив и что бы вы сделали по-другому?
#
# Кандидат: Внедрение скрама и код-ревью в предыдущем проекте улучшило планирование и распределение задач, а также повысило прозрачность и ответственность. Негативных последствий не было
#
#
# Рекрутер: 9. Вы говорили о важности идеи компании и команды. Как вы реагируете, если ваши ожидания от компании или
# команды не оправдываются?
#
# Кандидат: В таких ситуациях я стараюсь аргументировать свои предложения и показать их потенциальную ценность для команды и проекта. Если инициатива не принимается, я принимаю это как возможность пересмотреть свои предложения или найти другие пути для улучшения
#
#
# Рекрутер: 10. Вы упомянули, что можете отложить поездку с семьей ради работы. Как часто вы готовы жертвовать личными
# планами ради профессиональных обязанностей?
#
# Кандидат: Я готова к редким командировкам, примерно 1-2 раза в месяц, если это потребуется для выполнения задач и достижения целей проекта.

# %%
#@title Презентация компании

about_company_link = 'https://disk.yandex.ru/d/H5-jnef4OSya5Q'
download_from_yandex_disk(about_company_link, path_add_data)

with open(os.path.join(path_add_data, 'about_company.txt'), 'r', encoding='utf-8') as f:
    company_description = f.read()
present_company_and_vacancy(company_description)
# Out:
# Рекрутер: Спасибо, что ответили на все дополнительные вопросы. Теперь я хочу подробнее рассказать Вам о нашей
# организации. Нажмите Enter, когда будете готовы.
#
#
# О КОМПАНИИ
#
# Университет Искусственного Интеллекта — ведущий разработчик курсов и проектов по AI в России.
# С момента основания в 2018 году, компания добилась значительных успехов,
# достигнув оборота в 35 млн рублей в месяц.
# Мы лидируем в области образования по искусственному интеллекту
# и предоставляем самую большую базу контента по AI в мире.
# Наша команда состоит из 205 человек, все работают удаленно.
#
# Основные достижения и проекты:
# 1. Лидерство в обучении: Мы - ведущий разработчик курсов по искусственному интеллекту в России,
# опережаем конкурентов с огромным отрывом.
#
# 2. Ключевые проекты: Среди наших клиентов – РЖД, Ростелеком, Совкомбанк, Самолёт,
# Российская академия наук, Wildberries и Российский Университет Дружбы Народов (РУДН).
#
# 3. Выход на мировой рынок: Активно расширяем границы, ведем переговоры по продаже проектов
# на международных рынках, включая ОАЭ, Индию и Китай.
#
# 4. Фанаты искусственного интеллекта: Наша страсть и отдача AI не знает границ.
# Мы постоянно ищем новые способы применения инноваций для достижения революционных результатов.
#
# 5. Мы являемся первыми, кто создал нейро-куратора на базе ChatGPT,
# который обеспечивает быстрые и точные ответы на вопросы студентов 24/7.
# Этот инновационный инструмент интегрирован в нашу онлайн-платформу и помогает студентам в обучении
# и создании реальных проектов для ТОП компаний уже во время прохождения курса.
#
# 1. О компании
# Университет Искусственного Интеллекта (УИИ) — ведущий разработчик курсов и проектов по искусственному интеллекту (AI) в
# России. Основанный в 2018 году, УИИ за 5 лет достиг впечатляющих результатов, вырастив месячный оборот до 35 млн рублей.
# Мы стремимся к тому, чтобы оставаться лидером в области образования по AI, предлагая самую большую базу контента по
# искусственному интеллекту в мире. Наши студенты не только обучаются, но и ежегодно побеждают на крупнейших AI хакатонах
# страны, демонстрируя практическое применение полученных знаний.
# 2. Основные достижения и проекты
# 2.1. Лидерство в обучении:
# Мы - ведущий разработчик курсов по искусственному интеллекту в России, опережающий конкурентов с огромным отрывом. Наша
# платформа предлагает более 25 курсов, охватывающих широкий спектр тем, от основ AI до продвинутых техник машинного
# обучения и глубокого обучения.
# 2.2. Ключевые проекты:
# УИИ разрабатывает значимые проекты на заказ для различных крупных компаний и организаций. Среди наших клиентов - такие
# гиганты, как РЖД, Ростелеком, Совкомбанк, Самолёт, Российская академия наук, Wildberries и Российский Университет Дружбы
# Народов (РУДН). Эти проекты включают в себя создание сложных AI решений, автоматизацию бизнес-процессов и разработку
# интеллектуальных систем поддержки принятия решений.
# 2.3. Выход на мировой рынок:
# Мы активно расширяем свои границы, ведя переговоры по продаже наших проектов на международные рынки, включая ОАЭ, Индию
# и Китай. Этот процесс позволяет нам не только диверсифицировать свои источники дохода, но и обмениваться знаниями и
# технологиями с глобальными партнёрами.
# 3. Наша команда и инновации
# 3.1. Команда:
# УИИ гордится своей сплоченной командой из 205 человек, работающих на удаленке. Наша команда включает в себя
# высококвалифицированных специалистов в области AI, разработчиков, преподавателей и других профессионалов, которые
# совместно работают над достижением общих целей.
# 3.2. Инновации:
# Одним из наших ключевых инновационных достижений является разработка нейро-куратора на базе ChatGPT. Этот уникальный
# инструмент обеспечивает быстрые и точные ответы на вопросы студентов 24/7. Нейро-куратор интегрирован в нашу онлайн-
# платформу, предоставляя студентам непрерывную поддержку и помощь в обучении. Качество ответов нейро-куратора оценивается
# в 9.1 из 10 по результатам тестирования среди студентов УИИ, что превосходит средний показатель обычных кураторов,
# равный 8.8.
# 4. Признание и вклад
# 4.1. Признание:
# Наш университет заслужил признание не только в России, но и за её пределами. Мы регулярно участвуем в международных
# конференциях и форумах, делимся опытом и знаниями с другими профессионалами в области AI.
# 4.2. Вклад в сообщество:
# Мы активно участвуем в жизни AI сообщества, организуя хакатоны, конференции и другие мероприятия. Эти инициативы
# помогают нам поддерживать высокий уровень взаимодействия с нашей аудиторией и способствуют развитию новых талантов в
# области искусственного интеллекта.
# 5. Наши студенты
# 5.1. Обучение и проекты:
# Свыше 8 000 студентов прошли обучение в УИИ, создавая реальные проекты для топовых компаний уже во время прохождения
# курсов. Мы предоставляем студентам не только теоретические знания, но и практические навыки, необходимые для успешной
# карьеры в AI.
# 5.2. Поддержка:
# Наша платформа обеспечивает студентам всестороннюю поддержку, включая доступ к базе знаний, стажировкам и программам
# обучения. Мы стремимся сделать процесс обучения максимально комфортным и эффективным для каждого студента.
# 6. Наши цели и миссия
# 6.1. Цели:
# Основная цель УИИ - стать глобальным лидером в области образования и разработки AI. Мы постоянно работаем над улучшением
# качества наших курсов, внедрением новых технологий и расширением наших возможностей на международной арене.
# 6.2. Миссия:
# Наша миссия - предоставить качественное образование в области искусственного интеллекта, доступное каждому. Мы верим,
# что AI - это ключ к будущему, и стремимся подготовить наших студентов к вызовам и возможностям, которые принесет этот
# захватывающий и быстро развивающийся мир.
# В Университете Искусственного Интеллекта мы не просто обучаем AI, мы живем им. Наша страсть к искусственному интеллекту
# и стремление к инновациям помогают нам достигать невероятных высот и открывать новые горизонты. Присоединяйтесь к нам и
# станьте частью команды, которая меняет мир.
# 7.5. Этапы собеседования
# Процесс найма состоит из нескольких этапов:
# 7.5.1. Отклик на вакансию: Вы подаете заявку на участие в конкурсе.
# 7.5.2. Заполнение анкеты: Обязательный этап, без заполнения анкеты отклики не рассматриваются.
# 7.5.3. Онлайн-встреча с HR: Интервью с нашим HR специалистом. Интервью с нашим техническим специалистом для технических
# позиций.
# 7.5.4. Встреча с собственником компании: Личное знакомство и обсуждение деталей.
# 7.5.5. Добро пожаловать в команду! После успешного прохождения всех этапов вас ждет официальное приглашение на работу.
#
# Работа Университете Искусственного Интеллекта – это уникальная возможность для профессионала. Мы предлагаем не только
# конкурентную зарплату и гибкие условия работы, но и шанс стать частью компании, которая лидирует в области
# искусственного интеллекта и стремится к постоянному развитию и инновациям. Присоединяйтесь к нам и помогайте формировать
# будущее вместе с Университетом Искусственного Интеллекта!

# %%
#@title Ответы HR на вопросы кандидата

prompt_candidate_questions = f"""
Ты являешься опытным рекрутером, который знает всё о компании.
Ты только что успешно провел собеседование с кандидатом, теперь твоя задача - кратко, качественно
и вежливо ответить на все оставшиеся у кандидата вопросы. Если вопрос не относится к теме собеседования
или компании, то ты вежливо отвечаешь, что это не имеет значения к текущему собеседованию."""

query_candidate_questions_template = """
Пожалуйста, для ответа используй предоставленную Базу знаний для ответов.
Извлекай из базы знаний только ответы, которые указаны для позиции кандидата или ответы, универсальные для всех позиций.
Запрещаю двавать ответы из базы знаний, которые не соответстуют позиции кандидата.
Ответ напиши полным развернутым предложением. Не пиши слово: Ответ.
{candidate_question}."""

# Загружаем векторную базу ответов от HR
db_hr_answers = FAISS.load_local(folder_path=path_db_faiss,
                                 allow_dangerous_deserialization=True,
                                 embeddings=OpenAIEmbeddings(),
                                 index_name='db_hr_answers')

# Вопросы кандидата и генерация ответов HR (векторная база + OpenAI)
handle_candidate_questions(candidate_position, # в данном случае - Разработчик
                           prompt_candidate_questions,
                           query_candidate_questions_template,
                           db_hr_answers, # векторная база с ответами HR
                           model='gpt-4o')
# Out:
# Рекрутер: Если у Вас остались какие-либо вопросы, задайте их, пожалуйста, и я постараюсь ответить. Если вопросов нет,
# просто напишите "вопросов нет", и мы завершим наше собеседование.
#
#
# Кандидат: Какие сроки выплаты заработной платы и насколько они стабильны?
#
# Tokens used: 365 + 44 = 409. *** gpt-4o *** $ 0.00249
# Рекрутер: Выплаты заработной платы производятся раз в месяц, 15 числа. Если 15 число выпадает на выходные, то оплата придет в
# понедельник или вторник. Выплаты стабильны.
#
# Кандидат: Есть ли у вас премии и как они определяются?
#
# Tokens used: 371 + 14 = 385. *** gpt-4o *** $ 0.00206
# Рекрутер: Размер премии определяет руководитель на усмотрение собственника.
#
# Кандидат: Сколько человек в команде?
#
# Tokens used: 359 + 15 = 374. *** gpt-4o *** $ 0.00202
# Рекрутер: В компании работает 250 сотрудников. В вашем отделе 25 человек.
#
# Кандидат: Есть ли какие-то дополнительные бонусы или льготы для сотрудников?
#
# Tokens used: 348 + 13 = 361. *** gpt-4o *** $ 0.00194
# Рекрутер: Мы предлагаем выгодные условия обучения по AI, если станет интересно.
#
# Кандидат: Есть ли возможность карьерного роста?
#
# Tokens used: 362 + 25 = 387. *** gpt-4o *** $ 0.00218
# Рекрутер: Конечно, у нас редко кто засиживается на одном месте. Есть и горизонтальный, и вертикальный рост.
#
# Кандидат: вопросов нет
#
# Рекрутер: Спасибо за собеседование! Желаем Вам удачи!

# %% [markdown]
# ## **Отчет по кандидату**

# %%
#@title Ключевые требования к кандидату

system_key_requirements = """
Ты классный HR - специалист по подбору персонала."""

defining_key_requirements = f"""
# Ты подбираешь кандидата на эту вакансию: {vacancy}.
# Напиши 10 ключевых требований для кандидата, претендующего на эту вакансию.
Каждое требование пронумеруй и выводи с новой строки."""

key_requirements = generate_answer(system_key_requirements,
                                   defining_key_requirements,
                                   model='gpt-4o')
print(key_requirements)
# Out:
# Tokens used: 869 + 163 = 1032. *** gpt-4o *** $ 0.00679
# 1. Официальный опыт работы Python-разработчиком от 1 года.
# 2. Уверенное владение Python 3.7+.
# 3. Знание и опыт работы с библиотеками Pandas 1.3+ и Numpy.
# 4. Опыт разработки веб-приложений с использованием Django 2+ и Flask 2+.
# 5. Базовые навыки работы с HTML, CSS и Javascript.
# 6. Опыт работы с базами данных MySQL и PostgreSQL.
# 7. Умение работать с GIT-репозиториями.
# 8. Аналитический склад ума и высокая личная ответственность.
# 9. Способность работать в команде и эмпатия.
# 10. Готовность к обучению и развитию в области AI.

# %%
#@title **Выводим заключение о кандидате**

prompt_analysis = """
Ты классный специалист по подбору персонала. Твоя задача сделать строгий отчет по результатам
анализа диалога кандидата и рекрутера на собеседовании и аргументировать свои выводы.
"""
query_analysis = f"""
# Ты подбираешь кандидата на эту вакансию: {vacancy}.
# Проанализируй резюме и текст диалога между кандидатом и рекрутером на собеседовании, вот он: {interview_summary}.
# Необходимо также обратить свое внимание на эти основные критерии: {key_requirements}.
# Нужно обратить внимание на то, каких навыков и опыта не хватает кандидату по сравнению с требуемыми навыками из вакансии.
# Определи, какой навык является наиболее важным и базовым для указанной позиции в резюме.
  После этого, пожалуйста, рассчитай сумму месяцев временных интервалов для основного навыка
  исходя из опыта кандидата, если этот базовый навык упоминается в этом интервале.
  Необходимо учитывать все интервалы работы, в которых упоминается основной навык.
  Если в интервале работы нет упоминания об основном навыке, этот интервал не учитывается.
  Каков общий стаж в месяцах для основного навыка? Напиши основной навык и количество месяцев.
# В заключении напиши аргументированные выводы на сколько кандидат справился с вопросами,
насколько кандидат подходит на указанную вакансию.
"""
# Вызываем функцию итоговой оценки кандидата
analysis = generate_estimation(prompt_analysis, query_analysis, model='gpt-4o')
# Out:
# Итоговый отчет по кандидату:
#
# Tokens used: 5386 + 695 = 6081. *** gpt-4o *** $ 0.03735
# ### Анализ резюме и интервью кандидата
#
# #### Основные навыки и опыт кандидата:
#
# 1. **Официальный опыт работы Python-разработчиком**: 2 года 4 месяца.
# 2. **Python 3.7+**: Уверенное владение, используется в текущей работе.
# 3. **Библиотеки Pandas и Numpy**: Упоминаются в резюме и интервью, используются для обработки 3D данных.
# 4. **Flask**: Упоминается в резюме и интервью, опыт разработки веб-приложений.
# 5. **Django**: Нет практического опыта, но есть теоретические знания и готовность быстро освоить.
# 6. **HTML, CSS, Javascript**: Базовые навыки, упоминаются в резюме и интервью.
# 7. **PostgreSQL**: Упоминается в резюме и интервью, опыт работы.
# 8. **MySQL**: Нет опыта, но кандидат уверен в быстрой адаптации.
# 9. **GIT**: Упоминается в интервью, используется в работе.
# 10. **Аналитический склад ума и высокая личная ответственность**: Подтверждается примерами из интервью.
# 11. **Способность работать в команде и эмпатия**: Подтверждается примерами из интервью.
# 12. **Готовность к обучению и развитию в области AI**: Кандидат выражает желание углубить знания в AI.
#
# #### Недостающие навыки и опыт:
#
# 1. **Django**: Нет практического опыта, но кандидат готов быстро освоить.
# 2. **MySQL**: Нет опыта, но кандидат уверен в быстрой адаптации.
# 3. **Docker**: Нет практического опыта, но кандидат готов быстро освоить.
#
# #### Основной навык для позиции:
#
# Основной навык для данной позиции — **Python**. Кандидат имеет 2 года 4 месяца опыта работы с Python, что соответствует
# требованиям вакансии.
#
# #### Общий стаж в месяцах для основного навыка:
#
# - **Сентябрь 2022 — Май 2024 (1 год 9 месяцев)**: Работа в компании Скиллтеллект, использование Python.
# - **Февраль 2022 — Ноябрь 2022 (10 месяцев)**: Работа в университете, преподавание, но Python не упоминается.
#
# Общий стаж в месяцах для основного навыка (Python): 21 месяц.
#
# ### Аргументированные выводы:
#
# Кандидат обладает необходимым опытом и навыками для работы на позиции Python-разработчика в AI компании. Она уверенно
# владеет Python и связанными библиотеками, имеет опыт работы с Flask и PostgreSQL, а также базовые навыки в frontend-
# разработке. Несмотря на отсутствие практического опыта с Django и MySQL, кандидат демонстрирует готовность и способность
# быстро освоить эти технологии. Также она проявляет аналитический склад ума, высокую личную ответственность и способность
# работать в команде, что соответствует требованиям вакансии.
#
# Кандидат справилась с вопросами на интервью, демонстрируя уверенность в своих навыках и готовность к обучению. Она
# подходит на указанную вакансию, учитывая её опыт, навыки и стремление к развитию в области AI.

# %% [markdown]
# # Режим HR
# # Поиск подходящего резюме из базы на основе предоставленной вакансии.
# # Анализ. Собеседование с кандидатом (Руководитель отдела продаж).

# %%
#@title Поиск релевантных резюме под конкретную вакансию
from pprint import pprint as pp
# Для примера, берем вакансию Руководителя отдела продаж 'Head_of_sales.pdf.pdf'
vacancy = read_pdf(os.path.join(path_vacancies_pdf, 'Head_of_sales.pdf'))

# Загружаем векторную базу резюме.
db_vacancies = FAISS.load_local(folder_path=path_db_faiss,
                                allow_dangerous_deserialization=True,
                                embeddings=OpenAIEmbeddings(),
                                index_name='db_resumes')

# Поиск релевантных резюме под указанную вакансию.
similarity_info = scores_and_meta_similarity(vacancy, db_vacancies, k=5)
pp(similarity_info)
print(f"\nНаиболее подходящее резюме определено: {similarity_info[1][0]} с наименьшим значенинем score")

# Пробегаем по словарю для выбора русскоязычного названия позиции для ответов HR
for k, v in positions.items():
    if k in similarity_info[1][0]:
        candidate_position = v
print(f'Будут спользованы ответы от HR для позиции: {candidate_position}')

# Загружаем наиболее релевантное резюме по наименьшему значению score из поля Json файла
with open(os.path.join(path_resumes_json, f'{similarity_info[1][0]}.json'), 'r', encoding='utf-8') as f:
    resume_json_info = json.load(f)
    resume = resume_json_info['resume']
# Out:
# ([np.float32(0.23637988),
#   np.float32(0.2606039),
#   np.float32(0.2992475),
#   np.float32(0.30220526),
#   np.float32(0.34107858)],
#  ['Resume Head_of_sales+',
#   'Resume Head_of_sales-',
#   'Resume HR_Director-',
#   'Resume HR_Director+',
#   'Resume Python_Dev+'])
#
# Наиболее подходящее резюме определено: Resume Head_of_sales+ с наименьшим значенинем score
# Будут спользованы ответы от HR для позиции: Руководитель отдела продаж

# %%
#@title Типовые вопросы

# Загружаем файл general_questions.json
# В котором типовые вопросы для всех позиций ('Python_Dev', 'Head_of_sales', 'HR_Director')
general_questions_link = 'https://disk.yandex.ru/d/fT1nVglFz-g_Dg'
download_from_yandex_disk(general_questions_link, path_add_data)
with open(os.path.join(path_add_data, 'general_questions.json'), 'r', encoding='utf-8') as f:
    general_questions = json.load(f)

for key in general_questions:
    # название поля 'Head_of_sales' включает название позиции 'Resumes Head_of_sales+'
    if key in f'{similarity_info[1][0]}':
        # берем список вопросов на соответствующую позицию
        questions = general_questions[key]

# %%
#@title Начинаем собеседование

# Cоздание или очистка файла логов
open(os.path.join(path, '_log.txt'), 'w').close()

# Вызываем функцию старта собеседования
interview_summary = conduct_interview(resume)
# Out:
# Рекрутер: Здравствуйте! Давайте начнем собеседование. План собеседования следующий:
#  1. Я задам Вам несколько вопросов.
#  2. Расскажу о нашей компании и имеющейся вакансии
#  3. Отвечу на Ваши вопросы.
#  Общайтесь пожалуйста со мной как с обычным рекрутером!
#
# Рекрутер: Расскажите про Ваши самые значимые достижения в работе (2-3 примера).
#
# Кандидат: Создал с нуля команду 28 человек удаленно, закрывали план каждый месяц Создал дополнительно 5 новых команд с численностью 20+ человек, выполоняем план отдела
#
#
# Рекрутер: С какими тремя главными проблемами сталкивались в работе?
#
# Кандидат: Качество базы. Найм агентов. Изменения договора.
#
#
# Рекрутер: Какие навыки и качества вы считаете самыми важными в работе руководителя отдела продаж (РОПа)?
#
# Кандидат: 1) Умение решать проблемы. 2) Ответственность. 3) Быстро достигать поставленных целей.
#
#
# Рекрутер: Что для вас неприемлемо в работе?
#
# Кандидат: 1) Безответственность 2) Не заинтересованность
#
#
# Рекрутер: Расставьте в порядке приоритетности при выборе работы (от 1 до 7) : Доход; Удобный график работы; Идея
# компании (то, что компания несёт в мир); Стабильность компании; Статусность компании; Качественный продукт; Хорошее
# отношение руководителя
#
# Кандидат: 1)Стабильность компании 2)Доход 3)Идея компании 4)Хорошее отношения руководителя 5)Качественный продукт 6)Статус компании 7)Удобный график
#
#
# Рекрутер: Сколько максимум сотрудников у Вас было в подчинении?
#
# Кандидат: Сколько максимум сотрудников у Вас было в подчинении?
#
#
# Рекрутер: Сколько часов вы обычно работаете в неделю?
#
# Кандидат: 80
#
#
# Рекрутер: Ради чего вы готовы работать 80 часов в неделю?
#
# Кандидат: заработная плата.
#
#
# Рекрутер: На какой уровень дохода рассчитываете?
#
# Кандидат: от 160 тысяч рублей
#
#
# Рекрутер: Расставьте в порядке приоритетности (от более главного к менее главному): Деньги, Семья, Комфортная жизнь,
# Компания.
#
# Кандидат: 1)Деньги 2)Компания 3)Комфортная жизнь 4)Семья
#
#
# Рекрутер: Какой формат выбрали бы вы: 40 рабочих часов - 150 000 руб. в месяц; 60 рабочих часов - 200 000 руб. в месяц;
# 80 рабочих часов - 250 000 руб. в месяц?
#
# Кандидат: 80 рабочих часов - 250 000 в месяц.
#
#
# Рекрутер: Есть ли у Вас дети? Если да, напишите их возраст.
#
# Кандидат: нет
#
#
# Рекрутер: Планируете совмещать работу или мы будем для Вас единственным местом работы?
#
# Кандидат: единственным местом работы
#
#
# Рекрутер: Когда готовы приступить к работе?
#
# Кандидат:  через две недели
#
#
# Рекрутер: В понедельник Вам нужно сдать важный отчет. В пятницу, Вы понимаете, что не успеваете завершить эту задачу в
# рабочее время и нужно посвятить ей много времени на выходных. При этом вы уже пообещали семье, что в пятницу вечером,
# сразу после работы поедете на дачу, так как эта поездка была давно запланирована. Как поступите в данной ситуации?
#
# Кандидат: Буду работать на даче удалённо.
#
#
# Рекрутер: Перед вами стоит задача составить скрипт по работе менеджера с клиентом. Руководитель дал вам ещё
# дополнительно две объёмных задачи. Всё это необходимо решить до конца рабочего дня. Как вы поступите в данном кейсе?
#
# Кандидат: Расставлю приоритетность задач и начну их выполнять по порядку.
#
#
# Рекрутер: Вы подготовили отчет по Вашему отделу для Генерального директора, но выполнили его совсем не так, и
# руководитель даёт критику на него. Какие ваши действия / реакция?
#
# Кандидат: Приму критику, в дальнейшем не буду допускать подобных ошибок
#
#
# Рекрутер: Укажите следующие данные, по которым мы могли бы запросить рекомендацию по вам (можно несколько): Название
# компании. ФИО и должность того, кто смог бы вас порекомендовать. Контактный номер телефона этого человека.
#
# Кандидат: Компания ABC. Петров Петр Петрович. +7 123 456 78 99.
#
#
# Рекрутер: Есть ли у Вас опыт работы в сфере B2B?
#
# Кандидат: Есть. Удаленно привлекал фитнес клубы к сотрудничеству.
#
#
# Рекрутер: Готовы ли Вы работать с "холодными" продажами?
#
# Кандидат: да

# %%
#@title Генерируем дополнительные вопросы

prompt_additional_questions = f"""
Ты рекрутер, проводящий собеседование с кандидатом.
Твоя задача — задать 10 (десять) коротких и четких вопросов кандидату, чтобы выявить его навыки и опыт.
Ты очень критичный в отборе кандидатов и очень скептически относишься ко всем из словам, где кандидат хвалит себя.
"""
query_additional_questions = f"""
# Вот информация о кандидате (резюме, вопросы и ответы): \n{interview_summary}\n
# Ты подбираешь кандидата на вакансию: \n{vacancy}\n
# Задай вопросы на основании резюме кандидата, на основании ранее заданных вопросов
  кандидату и полученных от него ответов, а также вакансии.
# Нужно выявить дополнительную информацию, если этой информации ещё НЕ было в предыдущих ответах кандидата:
## Каких навыков и опыта НЕ хватает кандидату по сравнению с требуемыми навыками из вакансии.
   Навыки и опыт кандидата из резюме и из предыдущих ответов кандидата сравни с требованиями,
   предъявляемыми в вакансии и задай вопросы кандидату касательно навыков и опыта, которых кандидату НЕ достаточно.
## Мотивация, командная работа и коммуникационные навыки
# Задавай вопросы с новой строчки.
# Задай два неудобных или неожиданных вопроса, которые помогут выявить слабые стороны кандидата.
# Задай пару вопросов, направленных на выявление несоответствий в ответах кандидата с данными резюме кандидата.
# Не пиши тему вопроса и не разбивай их на группы, просто подай списком в случайном порядке.
# Задай 10 (десять) вопросов кандидату.
"""
# Генерация доп. вопросов
additional_questions = generate_dialogue(prompt_additional_questions,
                                         query_additional_questions, model="gpt-4o")
# Out:
# Рекрутер: Подождите минутку. Я проанализирую Ваши ответы и сформулирую дополнительные вопросы.
#
# Tokens used: 3306 + 329 = 3635. *** gpt-4o *** $ 0.02146
# 1. Вы упомянули, что работали с удаленными командами. Как вы обеспечиваете эффективное взаимодействие и мотивацию
# сотрудников на расстоянии?
#
# 2. В вашем резюме не указано, что вы работали с AmoCRM. Есть ли у вас опыт работы с этой системой или аналогичными CRM?
#
# 3. Как вы оцениваете свои аналитические способности и умение принимать решения на основе данных? Можете привести
# конкретный пример из вашей практики?
#
# 4. Вы упомянули, что готовы работать 80 часов в неделю ради заработной платы. Как это влияет на вашу продуктивность и
# качество работы?
#
# 5. В вашем резюме указано, что вы перевыполняли плановые показатели на 120%. Можете привести конкретные цифры или кейсы,
# подтверждающие это достижение?
#
# 6. Как вы справляетесь с ситуациями, когда команда не достигает поставленных целей? Какие меры предпринимаете для
# исправления ситуации?
#
# 7. Вы упомянули, что готовы работать с "холодными" продажами. Какой у вас был опыт в этой области и какие результаты вы
# достигли?
#
# 8. Как вы относитесь к критике и как используете ее для улучшения своей работы?
#
# 9. Вы указали, что готовы работать удаленно. Как вы организуете свое рабочее пространство и время, чтобы оставаться
# продуктивным?
#
# 10. Вы сказали, что ваша мотивация — заработная плата. Какие еще факторы могут повлиять на ваше решение остаться в
# компании на длительный срок?

# %%
#@title Задаем дополнительные вопросы
interview_summary += "\n".join(ask_additional_questions(additional_questions))
# Out:
# Рекрутер: 1. Вы упомянули, что работали с удаленными командами. Как вы обеспечиваете эффективное взаимодействие и
# мотивацию сотрудников на расстоянии?
#
# Кандидат: Мотивация удаленных сотрудников достигается через регулярное общение, установление четких целей и задач, а также внедрение системы поощрений за достижение результатов. Важно поддерживать корпоративную культуру и вовлеченность через виртуальные тимбилдинги и регулярные встречи. Также использую различные инструменты для мониторинга и оценки работы сотрудников, чтобы поддерживать высокий уровень дисциплины и производительности
#
#
# Рекрутер: 2. В вашем резюме не указано, что вы работали с AmoCRM. Есть ли у вас опыт работы с этой системой или
# аналогичными CRM?
#
# Кандидат: У меня есть опыт работы с AmoCRM. Использовал эту систему для автоматизации процессов продаж, что позволило сократить время обработки лидов на 20%. Кроме того, с помощью AmoCRM внедрил систему автоматических напоминаний, что повысило количество успешно закрытых сделок на 15%. Также анализировал данные из AmoCRM для оптимизации работы команды, что улучшило производительность каждого менеджера
#
#
# Рекрутер: 3. Как вы оцениваете свои аналитические способности и умение принимать решения на основе данных? Можете
# привести конкретный пример из вашей практики?
#
# Кандидат: Опыт работы с аналитическими данными включает сбор и анализ данных о продажах, эффективности сотрудников, рыночных трендах и конкурентной среде. Использую эти данные для принятия обоснованных решений, таких как корректировка стратегии продаж, изменение структуры команды и внедрение новых процессов. Например, анализ данных помог выявить наиболее эффективные каналы продаж и сфокусировать усилия на их развитии, что привело к увеличению конверсии на 25%
#
#
# Рекрутер: 4. Вы упомянули, что готовы работать 80 часов в неделю ради заработной платы. Как это влияет на вашу
# продуктивность и качество работы?
#
# Кандидат: Готовность работать 80 часов в неделю обусловлена желанием обеспечить высокий уровень дохода и добиться поставленных целей. При этом плавающие выходные позволяют более гибко распределять рабочее время и эффективно управлять личными и профессиональными обязательствами, что способствует сохранению баланса и поддержанию высокой производительности
#
#
# Рекрутер: 5. В вашем резюме указано, что вы перевыполняли плановые показатели на 120%. Можете привести конкретные цифры
# или кейсы, подтверждающие это достижение?
#
# Кандидат: Перевыполнил план по новым привлеченным клиентам на 120%, что привело к увеличению базы клиентов с 500 до 1100 за год. В ООО Мастер, перевыполнил план по объему продаж на 120%, увеличив выручку с 80 млн рублей до 112 млн рублей за два года работы
#
#
# Рекрутер: 6. Как вы справляетесь с ситуациями, когда команда не достигает поставленных целей? Какие меры предпринимаете
# для исправления ситуации?
#
# Кандидат: При обнаружении отклонений от плана, первым делом анализирую причины возникновения проблемы. Далее разрабатываю корректирующие действия, такие как дополнительное обучение сотрудников или корректировка стратегии продаж. Внедряю регулярные проверки и отчеты, чтобы оперативно выявлять и устранять потенциальные проблемы, а также мотивирую команду на достижение целей через дополнительные бонусы и поощрения
#
#
# Рекрутер: 7. Вы упомянули, что готовы работать с "холодными" продажами. Какой у вас был опыт в этой области и какие
# результаты вы достигли?
#
# Кандидат: На предыдущем месте работы, я увеличил продажи отдела на 35% за первый год, обеспечив рост выручки с 50 млн рублей до 67.5 млн рублей.
#
#
# Рекрутер: 8. Как вы относитесь к критике и как используете ее для улучшения своей работы?
#
# Кандидат: Конфликты внутри команды решаются путем открытого и конструктивного диалога, выявления причин конфликта и поиска взаимовыгодных решений
#
#
# Рекрутер: 9. Вы указали, что готовы работать удаленно. Как вы организуете свое рабочее пространство и время, чтобы
# оставаться продуктивным?
#
# Кандидат: Планирую четко разделять рабочее и личное время, используя гибкий график и эффективное планирование задач. Применяю тайм-менеджмент для управления временем и приоритетами, чтобы успешно выполнять рабочие обязанности, не пренебрегая личными обязательствами. Важно поддерживать баланс, чтобы сохранять высокую продуктивность и достигать поставленных целей как в профессиональной, так и в личной жизни
#
#
# Рекрутер: 10. Вы сказали, что ваша мотивация — заработная плата. Какие еще факторы могут повлиять на ваше решение
# остаться в компании на длительный срок?
#
# Кандидат: Справедливость, высокие цели, хороший коллектив

# %%
#@title Ответы на вопросы кандидата

prompt_candidate_questions = f"""
Ты являешься опытным рекрутером, который знает всё о компании.
Ты только что успешно провел собеседование с кандидатом, теперь твоя задача - кратко, качественно
и вежливо ответить на все оставшиеся у кандидата вопросы. Если вопрос не относится к теме собеседования
или компании, то ты вежливо отвечаешь, что это не имеет значения к текущему собеседованию."""

query_candidate_questions_template = """
Пожалуйста, для ответа используй предоставленную Базу знаний для ответов.
Извлекай из базы знаний только ответы, которые указаны для позиции кандидата или ответы, универсальные для всех позиций.
Запрещаю двавать ответы из базы знаний, которые не соответстуют позиции кандидата.
Ответ напиши полным развернутым предложением. Не пиши слово: Ответ.
{candidate_question}."""

# Загружаем векторную базу ответов от HR
db_hr_answers = FAISS.load_local(folder_path=path_db_faiss,
                                 allow_dangerous_deserialization=True,
                                 embeddings=OpenAIEmbeddings(),
                                 index_name='db_hr_answers')

# Вопросы кандидата и генерация ответов HR (векторная база + OpenAI)
handle_candidate_questions(candidate_position, # в данном случае - Руководитель отдела продаж
                           prompt_candidate_questions,
                           query_candidate_questions_template,
                           db_hr_answers, # векторная база с ответами HR
                           model='gpt-4o')
# Out:
# Рекрутер: Если у Вас остались какие-либо вопросы, задайте их, пожалуйста, и я постараюсь ответить. Если вопросов нет,
# просто напишите "вопросов нет", и мы завершим наше собеседование.
#
#
# Кандидат: Какие методики продаж вы используете? Это холодные или теплые звонки?
#
# Tokens used: 388 + 35 = 423. *** gpt-4o *** $ 0.00247
# Рекрутер: Заявки поступают на сайт, где ученики ознакамливаются и оставляют свои контакты, что делает их "теплыми" лидами.
#
# Кандидат:  Как вы определяете конверсии?
#
# Tokens used: 369 + 16 = 385. *** gpt-4o *** $ 0.00209
# Рекрутер: В Вашем отделе самая важная конверсия это лид-зум.
#
# Кандидат: Сколько человек в вашей команде?
#
# Tokens used: 378 + 32 = 410. *** gpt-4o *** $ 0.00237
# Рекрутер: В компании работает 250 человек. В отделе продаж, который вам предстоит возглавить, 15 опенеров и 1 тим-лид.
#
# Кандидат: Как организована структура вашей команды?
#
# Tokens used: 382 + 45 = 427. *** gpt-4o *** $ 0.00259
# Рекрутер: В отделе продаж структура организована следующим образом: в команде работают 15 опенеров, один тим-лид и руководитель
# отдела продаж (РОП). Ваше подчинение будет напрямую собственнику компании.
#
# Кандидат: Как у вас организована отчетность по выполненной работе?
#
# Tokens used: 367 + 29 = 396. *** gpt-4o *** $ 0.00227
# Рекрутер: Отчетность по выполненной работе организована ежедневно и еженедельно в гугл таблице, а также с использованием метрик.
#
# Кандидат: Какие инструменты вы используете для удаленной работы?
#
# Tokens used: 367 + 24 = 391. *** gpt-4o *** $ 0.00219
# Рекрутер: Мы используем AMO для управления процессами, общаемся в Telegram и проводим созвоны в Zoom.
#
# Кандидат: вопросов нет
#
# Рекрутер: Спасибо за собеседование! Желаем Вам удачи!

# %% [markdown]
# ## **Отчет по кандидату**

# %%
#@title Ключевые требования к кандидату

system_key_requirements = """
Ты классный HR - специалист по подбору персонала."""

defining_key_requirements = f"""
# Ты подбираешь кандидата на эту вакансию: {vacancy}.
# Напиши 10 ключевых требований для кандидата, претендующего на эту вакансию.
Каждое требование пронумеруй и выводи с новой строки."""

key_requirements = generate_answer(system_key_requirements,
                                   defining_key_requirements, model='gpt-4o')
print(key_requirements)
# Out:
# Tokens used: 1080 + 211 = 1291. *** gpt-4o *** $ 0.00856
# 1. Опыт работы на позиции руководителя отдела продаж (РОП) или руководителя колл-центра в B2C сегменте от 1 года.
# 2. Опыт управления коллективом от 10 человек в сфере клиентского сервиса.
# 3. Опыт управления удаленными командами.
# 4. Навыки построения эффективных отделов продаж, включая прямые продажи.
# 5. Аналитические способности и умение принимать решения на основе анализа данных.
# 6. Навыки подбора и обучения сотрудников.
# 7. Подтвержденный опыт увеличения продаж на предыдущем месте работы с конкретными кейсами в цифрах.
# 8. Опыт работы с CRM-системой AmoCRM.
# 9. Способность обеспечивать выполнение плана по zoom-презентациям и предпринимать упреждающие меры при отклонениях.
# 10. Умение улучшать систему работы, включая написание и доработку скриптов, шаблонов, отчетов и других инструментов продаж.

# %%
#@title **Выводим заключение о кандидате**

prompt_analysis = """
Ты классный специалист по подбору персонала. Твоя задача сделать строгий отчет по результатам
анализа диалога кандидата и рекрутера на собеседовании и аргументировать свои выводы.
"""
query_analysis = f"""
# Ты подбираешь кандидата на эту вакансию: {vacancy}.
# Проанализируй резюме и текст диалога между кандидатом и рекрутером на собеседовании, вот он: {interview_summary}.
# Необходимо также обратить свое внимание на эти основные критерии: {key_requirements}.
# Нужно обратить внимание на то, каких навыков и опыта не хватает кандидату по сравнению с требуемыми навыками из вакансии.
# Определи, какой навык является наиболее важным и базовым для указанной позиции в резюме.
  После этого, пожалуйста, рассчитай сумму месяцев временных интервалов для основного навыка
  исходя из опыта кандидата, если этот базовый навык упоминается в этом интервале.
  Необходимо учитывать все интервалы работы, в которых упоминается основной навык.
  Если в интервале работы нет упоминания об основном навыке, этот интервал не учитывается.
  Каков общий стаж в месяцах для основного навыка? Напиши основной навык и количество месяцев.
# В заключении напиши аргументированные выводы на сколько кандидат справился с вопросами,
насколько кандидат подходит на указанную вакансию.
"""
# Вызываем функцию итоговой оценки кандидата
analysis = generate_estimation(prompt_analysis, query_analysis, model='gpt-4o')
# Out:
# Итоговый отчет по кандидату:
#
# Tokens used: 4524 + 765 = 5289. *** gpt-4o *** $ 0.0341
# ### Анализ резюме и интервью кандидата
#
# #### Основные критерии вакансии и соответствие кандидата:
#
# 1. **Опыт работы на позиции руководителя отдела продаж (РОП) или руководителя колл-центра в B2C сегменте от 1 года.**
#    - Кандидат имеет опыт работы в качестве руководителя дистанционных продаж малого бизнеса в ПАО РОСБАНК (1 год 11
# месяцев) и старшего менеджера отдела продаж в ООО Мастер (2 года 2 месяца). Однако, его опыт в B2C сегменте не был явно
# указан, что может быть недостатком.
#
# 2. **Опыт управления коллективом от 10 человек в сфере клиентского сервиса.**
#    - Кандидат управлял командой из 20 сотрудников в ПАО РОСБАНК, что соответствует требованию.
#
# 3. **Опыт управления удаленными командами.**
#    - Кандидат упомянул создание и управление удаленными командами, что соответствует требованию.
#
# 4. **Навыки построения эффективных отделов продаж, включая прямые продажи.**
#    - Кандидат имеет опыт в развитии и реализации стратегий продаж, что подтверждается его достижениями.
#
# 5. **Аналитические способности и умение принимать решения на основе анализа данных.**
#    - Кандидат продемонстрировал аналитические способности, приводя примеры использования данных для принятия решений.
#
# 6. **Навыки подбора и обучения сотрудников.**
#    - Кандидат имеет опыт в обучении и мотивации персонала.
#
# 7. **Подтвержденный опыт увеличения продаж на предыдущем месте работы с конкретными кейсами в цифрах.**
#    - Кандидат предоставил конкретные кейсы увеличения продаж и выполнения планов.
#
# 8. **Опыт работы с CRM-системой AmoCRM.**
#    - Кандидат подтвердил опыт работы с AmoCRM.
#
# 9. **Способность обеспечивать выполнение плана по zoom-презентациям и предпринимать упреждающие меры при отклонениях.**
#    - Кандидат не предоставил конкретных примеров, связанных с zoom-презентациями.
#
# 10. **Умение улучшать систему работы, включая написание и доработку скриптов, шаблонов, отчетов и других инструментов
# продаж.**
#     - Кандидат упомянул опыт в улучшении процессов и внедрении новых форматов отчетности.
#
# #### Основной навык и его стаж:
#
# - **Основной навык:** Управление продажами
# - **Стаж в месяцах:**
#   - ПАО РОСБАНК: 1 год 11 месяцев (23 месяца)
#   - ООО Мастер: 2 года 2 месяца (26 месяцев)
#   - **Общий стаж:** 49 месяцев
#
# #### Аргументированные выводы:
#
# Кандидат обладает значительным опытом в управлении продажами и командой, что подтверждается его достижениями и
# конкретными кейсами. Он соответствует большинству требований вакансии, включая опыт работы с удаленными командами и
# навыки аналитики. Однако, его опыт в B2C сегменте не был явно указан, что может быть недостатком. Кандидат также
# продемонстрировал готовность работать в интенсивном режиме, что соответствует условиям вакансии.
#
# Кандидат справился с вопросами на собеседовании, предоставив конкретные примеры и демонстрируя уверенность в своих
# навыках. Он подходит на указанную вакансию, однако стоит уточнить его опыт в B2C сегменте для полного соответствия
# требованиям.
